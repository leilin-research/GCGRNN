# %%
import tensorflow as tf
import numpy as np
import scipy.sparse as sp
from scipy.sparse.linalg.eigen.arpack import eigsh
import scipy.sparse as sp
import pandas as pd
import pickle
from datetime import timedelta
import matplotlib.pyplot as plt
from scipy.stats.stats import pearsonr
#from tensorflow.contrib.rnn.python.ops import rnn_cell as RNNCell
from tensorflow.python.ops.rnn_cell_impl import _RNNCell as RNNCell
import collections
from tensorflow.contrib import rnn
import h5py
#from tensorflow.python.ops.rnn_cell_impl import _RNNCell 
import random

# %%
def normalize_adj(adj):
    """Symmetrically normalize adjacency matrix."""
    #adj[np.isnan(adj)] = 0.
    adj = tf.abs(adj)
    rowsum = tf.reduce_sum(adj, 1)# sum by row

    d_inv_sqrt = tf.pow(rowsum, -0.5)
   
    #d_inv_sqrt[np.isinf(d_inv_sqrt)] = 0.
    
    d_mat_inv_sqrt = tf.diag(d_inv_sqrt)

    return tf.matmul(tf.matmul(d_mat_inv_sqrt, adj), d_mat_inv_sqrt)

def masked_mae_tf(preds, labels, null_val=np.nan):
    """
    Accuracy with masking.
    :param preds:
    :param labels:
    :param null_val:
    :return:
    """
    if np.isnan(null_val):
        mask = ~tf.is_nan(labels)
    else:
        mask = tf.not_equal(labels, null_val)
    mask = tf.cast(mask, tf.float32)
    mask /= tf.reduce_mean(mask)
    mask = tf.where(tf.is_nan(mask), tf.zeros_like(mask), mask)
    loss = tf.abs(tf.subtract(preds, labels))
    loss = loss * mask
    loss = tf.where(tf.is_nan(loss), tf.zeros_like(loss), loss)
    return tf.reduce_mean(loss)

# %%
class StandardScaler:
    """
    Standard the input
    """

    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def transform(self, data):
        return (data - self.mean) / self.std

    def inverse_transform(self, data):
        return (data * self.std) + self.mean

# %%
# install tables
raw_data = pd.read_hdf('../../data/METR-LA/metr-la.h5')

# %%
raw_data.shape
# Out:
# (34272, 207)

# %%
raw_data.head()
# Out:
#                         773869     767541     767542     717447     717446  \
# 2012-03-01 00:00:00  64.375000  67.625000  67.125000  61.500000  66.875000
# 2012-03-01 00:05:00  62.666667  68.555556  65.444444  62.444444  64.444444
# 2012-03-01 00:10:00  64.000000  63.750000  60.000000  59.000000  66.500000
# 2012-03-01 00:15:00   0.000000   0.000000   0.000000   0.000000   0.000000
# 2012-03-01 00:20:00   0.000000   0.000000   0.000000   0.000000   0.000000
#
#                         717445  773062  767620     737529     717816  ...  \
# 2012-03-01 00:00:00  68.750000  65.125  67.125  59.625000  62.750000  ...
# 2012-03-01 00:05:00  68.111111  65.000  65.000  57.444444  63.333333  ...
# 2012-03-01 00:10:00  66.250000  64.500  64.250  63.875000  65.375000  ...
# 2012-03-01 00:15:00   0.000000   0.000   0.000   0.000000   0.000000  ...
# 2012-03-01 00:20:00   0.000000   0.000   0.000   0.000000   0.000000  ...
#
#                         772167  769372     774204     769806  717590  \
# 2012-03-01 00:00:00  45.625000  65.500  64.500000  66.428571  66.875
# 2012-03-01 00:05:00  50.666667  69.875  66.666667  58.555556  62.000
# 2012-03-01 00:10:00  44.125000  69.000  56.500000  59.250000  68.125
# 2012-03-01 00:15:00   0.000000   0.000   0.000000   0.000000   0.000
# 2012-03-01 00:20:00   0.000000   0.000   0.000000   0.000000   0.000
#
#                         717592     717595     772168     718141  769373
# 2012-03-01 00:00:00  59.375000  69.000000  59.250000  69.000000  61.875
# 2012-03-01 00:05:00  61.111111  64.444444  55.888889  68.444444  62.875
# 2012-03-01 00:10:00  62.500000  65.625000  61.375000  69.857143  62.000
# 2012-03-01 00:15:00   0.000000   0.000000   0.000000   0.000000   0.000
# 2012-03-01 00:20:00   0.000000   0.000000   0.000000   0.000000   0.000
#
# [5 rows x 207 columns]

# %%
# Create model
def gcn(x, weights, biases, batch_size, n_input, frequency,flag, n_output_vec):
    # Hidden layer with RELU activation
    
   # output_list = tf.Variable(tf.zeros([n_output_vec,1]),dtype=tf.float32) #'Tensor' object does not support item assignment, cant build Ypre

    #Xtem = tf.reshape(x[i,:], [n_input, frequency])
    #Xtem = tf.transpose(Xtem)
    #Atem = tf.convert_to_tensor(A_whole_final, dtype=np.float32)
    #Atem1 = tf.diag(tf.ones([n_input])) # Atem not palying any roles
    #Ytem = tf.reshape(Y[i,:], [n_input, 1])
    #Atem = tf.diag(tf.ones([n_input]))
    #x = tf.reshape(x, [-1, sn, 1]) # 100, 207, 1
    
    # x (?, 207, 12)
    x = tf.transpose(x, [1, 0, 2]) # 207, ?, 12
    x = tf.reshape(x, [sn, -1]) # 207, batch*feature_num
    Atem1 = 0.5*(weights['A1'] + tf.transpose(weights['A1']))#+ Atem 
    Atem1 = normalize_adj(Atem1)
    #th = tf.constant(0.01, dtype=tf.float32)
    #where = tf.subtract(Atem1, th)
    #Atem1 = tf.nn.relu(where)

    Z1 = tf.matmul(Atem1, x) # 207, batch*feature_num  #+ tf.matmul( tf.matmul(weights['A1'], weights['A1']), Xtem)
    Z1 = tf.reshape(Z1, [-1, frequency]) # 207* 100, frequency
    #layer_1 = tf.matmul(Z1, weights['h1']) 
    layer_1 = tf.add(tf.matmul(Z1, weights['h1']), biases['b1'])
    layer_1 = tf.nn.relu(layer_1) # 207*100, hidden1

    
    Atem2 = 0.5*(weights['A2'] + tf.transpose(weights['A2']))#+ Atem 
    Atem2 = normalize_adj(Atem2)
    
    layer_1 = tf.reshape(layer_1, [sn, -1])  # 207, batchsize*hidden1
    Z2 = tf.matmul(Atem2, layer_1)
    Z2 = tf.reshape(Z2, [-1, n_hidden_vec1]) # 207*batchsize, n_hidden_vec1
    layer_2 = tf.add(tf.matmul(Z2, weights['h2']), biases['b2'])
    layer_2 = tf.nn.relu(layer_2) # 207*batchsize, hidden2

    Atem3 = 0.5*(weights['A3'] + tf.transpose(weights['A3']))#+ Atem 
    Atem3 = normalize_adj(Atem3) 
    
    layer_2 = tf.reshape(layer_2, [sn, -1])  # 207, batchsize*hidden2
    Z3 = tf.matmul(Atem3, layer_2)
    Z3 = tf.reshape(Z3, [-1, n_hidden_vec2]) # 207*batchsize, hidden2
    layer_3 = tf.add(tf.matmul(Z3, weights['h3']), biases['b3'])
    layer_3 = tf.nn.relu(layer_3) # 207*batchsize, hidden3
    
    #Atem4 = 0.5*(weights['A4'] + tf.transpose(weights['A4']))#+ Atem 
    #Atem4 = normalize_adj(Atem4)
    #Z4 = tf.matmul(Atem4, layer_3)
    #layer_4 = tf.add(tf.matmul(Z4, weights['h4']), biases['b4'])
    #layer_4 = tf.nn.relu(layer_4)

    # flattern
    #layer_3 = tf.reshape(layer_3, [1, 272*n_hidden_vec3])

    #F1 = tf.add(tf.matmul(layer_3, weights['f1']), biases['bf1'])
    #F1 = tf.nn.relu(F1)

    #F2 = tf.add(tf.matmul(F1, weights['f2']), biases['bf2'])
    #F2 = tf.nn.relu(F2)

    #F3 = tf.add(tf.matmul(F1, weights['f3']), biases['bf3'])
    #out_layer = tf.reshape(F3, [272, 1])

    # Output layer with linear activation
    #layer_1 = tf.reshape(layer_1, [sn, -1, n_hidden_vec1])
    #layer_1 = tf.transpose(layer_1, [1, 0, 2]) # batchsize, sn, hidden3
    #layer_1 = tf.reshape(layer_1, [-1, n_hidden_vec1]) # batchsize * sn, hidden3
    
    out_layer = tf.add(tf.matmul(layer_3, weights['out']), biases['bout'])  # 207*100, horizon
    out_layer = tf.reshape(out_layer, [sn, -1, horizon]) # 207, 100, horizon
    out_layer = tf.transpose(out_layer, [1, 0, 2]) # 100, 207, horizon
    out_layer = tf.reshape(out_layer, [-1, sn*horizon]) # 100, 207*horizon
    #tf.matmul(Atem1, layer_1)#tf.matmul(Atem, layer_3)
    #out_layer = tf.add(tf.matmul(Z4, weights['out']), biases['bout'])
    #out_layer = tf.nn.relu(out_layer)
    # weather layer 1
    #x_wea_tem = tf.reshape(x_wea[i,:], [1, 9*frequency2]) # 1 by 126
    #layer_1_wea = tf.add(tf.matmul(x_wea_tem, weights['h1_wea']), biases['b1_wea'])
    #layer_1_wea = tf.nn.relu(layer_1_wea)

    #out_layer_wea = tf.add(tf.matmul(layer_1_wea, weights['out_wea']), biases['bout_wea'])
    #out_layer = tf.add(out_layer, tf.reshape(out_layer_wea, [272, 1]))


    
    return out_layer

# %%
def gcn_corr_final(frequency, horizon, learning_rate, decay,batch_size, n_hidden_vec1,n_hidden_vec2,n_hidden_vec3,keep, early_stop_th,training_epochs, reg1, reg2):
    # set size
    #sn = 3 # station number
    X_whole = []
    Y_whole = []

    x_offsets = np.sort(
        # np.concatenate(([-week_size + 1, -day_size + 1], np.arange(-11, 1, 1)))
        np.concatenate((np.arange(-frequency+1, 1, 1),))
    )
    # Predict the next one hour
    y_offsets = np.sort(np.arange(1, 1+ horizon, 1))

    min_t = abs(min(x_offsets))
    max_t = abs(raw_data.shape[0] - abs(max(y_offsets)))  # Exclusive
    for t in range(min_t, max_t):
        x_t = raw_data.iloc[t + x_offsets, 0:sn].values.flatten('F')
        y_t = raw_data.iloc[t + y_offsets, 0:sn].values.flatten('F')
        X_whole.append(x_t)
        Y_whole.append(y_t)

    X_whole = np.stack(X_whole, axis=0)
    Y_whole = np.stack(Y_whole, axis=0)
    
    
    '''
    time_step = int(time_step) #

    #i = time_step
    #X_whole = np.zeros(shape = (raw_data.shape[0] - time_step, sn*time_step), dtype = np.float)
    #Y_whole = np.zeros(shape = (raw_data.shape[0] - time_step, sn), dtype = np.float)

    while i < raw_data.shape[0]:
        X_whole[i - time_step, ] = raw_data.iloc[(i - time_step):i, 0:sn].values.flatten('F') # 'F' flatten by column, default:flatten by row 0, 1, 2...7
        Y_whole[i - time_step, ] = raw_data.iloc[i, 0:sn]
        i = i + 1
    '''
    time_step = int(X_whole.shape[1] / sn)

    n_input = sn # station number
    n_input_vec = n_input * frequency # 207 * frequency
    n_A_vec = n_input * n_input
    n_output_vec = Y_whole.shape[1] # each row represent a result
    #print (n_output_vec)

    X_whole = np.reshape(X_whole, [X_whole.shape[0], sn, time_step])
    num_samples = X_whole.shape[0]
    num_test = round(num_samples * 0.2)
    num_train = round(num_samples * 0.7)
    num_val = num_samples - num_test - num_train
    #skip = skip1 + freq_max - time_step#time_step_max - time_step # to make sure the testing datasets are the same although the frequency could be different

    X_training = X_whole[:num_train, :]
    Y_training = Y_whole[:num_train, :]
    
    # shuffle
    perm = np.arange(X_training.shape[0])
    np.random.shuffle(perm)
    X_training = X_training[perm]
    Y_training = Y_training[perm]
    
    #print (type(X_training))
    #X_training = random.Random(6).shuffle(X_training)
    #Y_training = random.Random(6).shuffle(Y_training)

    X_val = X_whole[num_train:num_train+num_val, :]
    Y_val = Y_whole[num_train:num_train+num_val, :]
    #A_val = A_whole[0+training:0+training+validation, :]

    X_test = X_whole[-num_test:, :]
    Y_test = Y_whole[-num_test:, :]

    scaler = StandardScaler(mean=X_training.mean(), std=X_training.std())

    X_training = scaler.transform(X_training)
    Y_training = scaler.transform(Y_training)

    X_val = scaler.transform(X_val)
    Y_val = scaler.transform(Y_val)

    X_test = scaler.transform(X_test)
    Y_test = scaler.transform(Y_test)
    
    early_stop_th = int(early_stop_th)
    training_epochs = int(training_epochs)
    
    early_stop_k=0
    display_step = 1
    best_val = 10000
    traing_error = 0
    test_error = 0
    predic_res = []
    predic_step = []

    tf.reset_default_graph()

    keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)
    
    
    batch_size = int(batch_size)
    n_hidden_vec1 = int(n_hidden_vec1)
    n_hidden_vec2 = int(n_hidden_vec2)
    n_hidden_vec3 = int(n_hidden_vec3)
    early_stop_th = int(early_stop_th)
    training_epochs = int(training_epochs)
    
    early_stop_k=0
    display_step = 1
    best_val = 10000
    traing_error = 0
    test_error = 0
    # Network Parameters

    #n_classes = 2 # MNIST total classes (0-9 digits) # n_classes is for classification only

    tf.reset_default_graph()

    # tf Graph input
    X = tf.placeholder(tf.float32, [None, sn, time_step]) # X is the input signal
    #X_weather = tf.placeholder(tf.float32, [None, 9 * frequency2]) # X_weather weather and holiday information (9 is the feature number)
    A = tf.placeholder(tf.float32, [None, n_A_vec]) # A is the normalized adj matrix
    oldA = tf.placeholder(tf.float32, [n_input, n_input])
    Y = tf.placeholder(tf.float32, [None, n_output_vec]) # y is the regression output

    #Xtem = tf.placeholder(tf.float32, [n_input, frequency]) # for each row of X, A, Y, it can be reshaped to Xtem, Atem, Ytem
    #Atem = tf.placeholder(tf.float32, [n_input, n_input]) # 
    #Ytem = tf.placeholder(tf.float32, [n_input, 1]) #

    #Ypre = tf.placeholder(tf.float32, [None, n_output_vec])

    keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

    # Store layers weight & bias
    weights = {
        'h1': tf.Variable(tf.random_normal([frequency, n_hidden_vec1])),
        'h2': tf.Variable(tf.random_normal([n_hidden_vec1, n_hidden_vec2])),
        'h3': tf.Variable(tf.random_normal([n_hidden_vec2, n_hidden_vec3])),
        #'h4': tf.Variable(tf.random_normal([n_hidden_vec3, n_hidden_vec4])),
        'out': tf.Variable(tf.random_normal([n_hidden_vec3, horizon])), # dont forget to change n_hidden_vec1 when add/delete layers
        #'f1': tf.Variable(tf.random_normal([272*n_hidden_vec3, 100])),
        #'f2': tf.Variable(tf.random_normal([50, 10])),
        #'f3': tf.Variable(tf.random_normal([100, 272])),
        'A1': tf.Variable(tf.random_normal([n_input,n_input])),
        'A2': tf.Variable(tf.random_normal([n_input,n_input])),
        'A3': tf.Variable(tf.random_normal([n_input,n_input])),
        #'A4': tf.Variable(tf.random_normal([n_input,n_input])),
        #'h1_wea': tf.Variable(tf.random_normal([9*frequency2, n_hidden_weather1])),
        #'out_wea': tf.Variable(tf.random_normal([n_hidden_weather1, n_input]))
    }
    biases = {
        'b1': tf.Variable(tf.random_normal([1,n_hidden_vec1])),# n_hidden_vec1])),# bias all the same??? dont forget to test
        'b2': tf.Variable(tf.random_normal([1, n_hidden_vec2])), #n_hidden_vec2])),
        'b3': tf.Variable(tf.random_normal([1, n_hidden_vec3])),#n_hidden_vec3])),
        #'b4': tf.Variable(tf.random_normal([n_input, n_hidden_vec4])),
        #'b1': tf.Variable(tf.random_normal([n_input,n_hidden_vec1])),# bias all the same??? dont forget to test
        #'b2': tf.Variable(tf.random_normal([n_input,n_hidden_vec2])),
        #'b3': tf.Variable(tf.random_normal([n_input,n_hidden_vec3])),
        #'bf1': tf.Variable(tf.random_normal([1, 100])), 
        #'bf2': tf.Variable(tf.random_normal([1, 10])), 
        #'bf3': tf.Variable(tf.random_normal([1, 272])), 
        'bout': tf.Variable(tf.random_normal([1, horizon])), 
        #'b1_wea': tf.Variable(tf.random_normal([1, n_hidden_weather1])), 
        #'bout_wea': tf.Variable(tf.random_normal([1, n_input])), 
    }

    #gcn_no_A
    #gcn
    # Construct model
    pred= gcn(X, weights, biases, batch_size,n_input, frequency, 1, n_output_vec)
    #print ('here!!!!!!!!!!!!!!!!')
    #set  negative in pred to 0s
    #Computes rectified linear: max(features, 0).
    #pred = tf.nn.relu(pred)
    # Define loss and optimizer
    # RMS for regression 
    # L2 regularization
    #cost = tf.reduce_mean(tf.pow(pred-Y, 2)) + reg1*tf.nn.l2_loss(weights['A1']) + reg2*tf.nn.l2_loss(weights['A2'])# + tf.nn.l2_loss(weights['A2']) + tf.nn.l2_loss(weights['A3'])))

    # L1 regular tf.reduce_sum(tf.abs(parameters))
    # mae
    
    pred = scaler.inverse_transform(pred)
    Y_true_tr = scaler.inverse_transform(Y)

    cost = masked_mae_tf(pred, Y_true_tr, 0)#+ reg1*tf.reduce_sum(tf.abs(weights['A1'])) +  reg2*tf.reduce_sum(tf.abs(weights['A2'])) + reg3*tf.reduce_sum(tf.abs(weights['A3']))#tf.reduce_mean(tf.abs(pred-Y_true_tr))# + reg1*tf.reduce_sum(tf.abs(weights['A1']))
    #cost = tf.reduce_mean(tf.pow(pred-Y, 2)) + reg1*tf.reduce_sum(tf.abs(weights['A1']))# + reg2*tf.reduce_sum(tf.abs(weights['A2']))
    pred_val= gcn(X, weights, biases, batch_size,n_input,frequency, 2, n_output_vec)
    #pred_val = tf.nn.relu(pred_val)
    #mae 
    pred_val = scaler.inverse_transform(pred_val)
    Y_true_val = scaler.inverse_transform(Y)
    cost_val = masked_mae_tf(pred_val, Y_true_val, 0)#tf.reduce_mean(tf.abs(pred_val-Y_true_val))
    #cost_val = tf.reduce_mean(tf.pow(pred_val-Y, 2))

    pred_tes= gcn(X, weights, biases, batch_size,n_input,frequency, 3, n_output_vec)
    #pred_tes = tf.nn.relu(pred_tes)
    # mae
    pred_tes = scaler.inverse_transform(pred_tes)
    Y_true_tes = scaler.inverse_transform(Y)
    '''
    predic_res_re = tf.reshape(pred_tes, [Y_test.shape[0], sn, horizon])
    test_Y_re = tf.reshape(Y_true_tes, [Y_test.shape[0], sn, horizon])
    
    cost_by_hor = []
    for hor_i in range(horizon):
        cost_by_hor.append(masked_mae_tf(predic_res_re[:, :, 0:hor_i], test_Y_re[:, :, 0:hor_i], 0))
    '''
    cost_tes = masked_mae_tf(pred_tes, Y_true_tes, 0)#tf.reduce_mean(tf.abs(pred_tes-Y_true_tes))
    #rmse
    #cost_tes = tf.reduce_mean(tf.pow(pred_tes-Y, 2))
    # cross-entropy for classification
    # cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=Y_train))
    # ratio = tf.abs(tf.reduce_sum(pred)-tf.reduce_sum(Y))/tf.reduce_sum(Y)
    #zero = 0
    #ratio = tf.reduce_mean(tf.divide(tf.where(tf.not_equal(Y, zero), np.abs(pred-Y), tf.zeros(Y.get_shape(), tf.float32)), tf.where(tf.not_equal(Y, zero), Y, tf.ones(Y.get_shape(), tf.float32))))
    #optimizer = tf.train.RMSPropOptimizer(learning_rate, decay).minimize(cost)
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

    # Initializing the variables
    init = tf.global_variables_initializer()
    saver = tf.train.Saver()

    #total_val_cost = []
    #total_val_ratio = []

    # learning start from 

    #index = daily_bike[(daily_bike['year'] == 2016) & (daily_bike['monthofyear'] == 1) & (daily_bike['dayofmonth'] == 1)].index.tolist()[0]
    #A_hat = normalize_adj(corr_matrix_trips)
    #print(A_hat)


    with tf.Session() as sess:
        sess.run(init)

        for epoch in range(training_epochs):

            avg_cost = 0.
            total_batch = int(num_train/batch_size)

            for i in range(total_batch):
                #print (Y_training[i*batch_size:(i+1)*batch_size,].size())
                _, c, preds, trueval = sess.run([optimizer, cost, pred, Y_true_tr], feed_dict={X: X_training[i*batch_size:(i+1)*batch_size,], 
                                                      Y: Y_training[i*batch_size:(i+1)*batch_size,], 
                                                              keep_prob: keep})
                #print (preds)
                #print (trueval)
                #print ("Epoch:", '%04d' % (epoch+1), "batch: ", i, "batch cost=", \
                #    "{:.9f}".format(c))
                #print ('here!!!!!!!!!!!!!!!!')
                avg_cost += c * batch_size #/ total_batch 
                #Display logs per epoch step
                
            # rest part of training dataset
            #num = num_train - total_batch*batch_size 
            if total_batch * batch_size != num_train:
                _, c, preds, trueval = sess.run([optimizer, cost, pred, Y_true_tr], feed_dict={X: X_training[total_batch*batch_size:num_train,], 
                                          Y: Y_training[total_batch*batch_size:num_train,],
                                                  keep_prob: keep})
                avg_cost += c * (num_train - total_batch*batch_size)
            
            avg_cost = avg_cost / num_train
            
            if epoch % display_step == 0:
                print ("Epoch:", '%04d' % (epoch+1), "Training MAE=", \
                    "{:.9f}".format(avg_cost)) #np.sqrt(avg_cost)
            # validation
            c_val = sess.run([cost_val], feed_dict={X: X_val, Y: Y_val,  keep_prob:1})
            print("Validation MAE: ", c_val[0])

            c_tes, pred_tes1, A1, Y_true = sess.run([cost_tes, pred_tes, weights['A1'], Y_true_tes], feed_dict={X: X_test,Y: Y_test, keep_prob: 1})
            print("Test MAE: ", c_tes)
            #print("predic step: ", cost_by_hor)

            if c_val[0] < best_val:
                best_val = c_val[0]
                #saver.save(sess, './bikesharing_graph_2_th_point1')
                test_error = c_tes
                traing_error = avg_cost#np.sqrt(avg_cost)
                early_stop_k = 0 # reset to 0
                #print (pred_tes1)
                predic_res = pred_tes1
                #predic_step = cost_by_hor

            # early stopping
            if c_val[0] >= best_val:
                early_stop_k += 1

            # threshold
            if early_stop_k == early_stop_th:
              #  print ("early stopping...")
                break
            

        print("epoch is ", epoch)
        print("training error is ", traing_error)
        print("Optimization Finished! the lowest validation MAE is ", best_val)#(np.sqrt(best_val)))
        print("The test MAE is ", test_error)#(np.sqrt(test_error)))
    
    test_Y = Y_test
    test_error = np.sqrt(test_error)
    return -best_val, predic_res,Y_true,test_error, A1#, predic_step#, A2

# %%
# increas batch size from 100 to 1000: validation error 39.XX at about 100 epochs
# batch size to 50: validation error 6.XX at about 100 epochs
# add one more gcn layer: 8.XX
# increase learning rate to 0.01, batch size is 100: 10.XX
# decrease learning rate to 0.005, batch size is 100: 10.XX
# decrease learning rate to 0.005, batch size is 50, two hidden levels (same matrix):
    # 6.XX at 100th epoch
# decrease learning rate to 0.005, batch size is 50, one hidden level, hidden 40:
    # 6.XX at 100th epoch
# decrease learning rate to 0.005, batch size is 50, one hidden level, hidden 20:
    # drop much faster
    # 6.XX can be get, but kind of overfitting at 100th epoch?
# decrease learning rate to 0.005, batch size is 50, one hidden level, hidden 10:
    # drop much faster
    #  at 100th epoch
# learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #reduce prediction horizon from 12 to 1, normalize the data:
    # val: 3.16

# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #reduce prediction horizon from 12 to 1, normalize the data, normalize the symmetric adjacency matrix:
    # train: 3.24, val: 3.42
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #reduce prediction horizon from 12 to 1, normalize the data, normalize the symmetric adjacency matrix, 
    # train: 3.08, val: 3.26
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #reduce prediction horizon from 12 to 1, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper
    # train: 2.82, val: 2.75
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, one layer
    # train: 4.08, val: 3.99, test: 4.29 
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, two layers (same adjmatrix)
    # train: 4.10, val: 4.19, test: 4.54 
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, two layers (different adjmatrix)
    # train: 3.52, val: 3.62, test: 4.03
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, two layers (different adjmatrix), bias set as a vector of same length
    # train: 3.53, val: 3.58, test: 3.91 
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, three layers (three adjmatrix), bias set as a vector of same length
    # batch from 50 to 100
    # train: 3.36, val: 3.42, test: 3.82
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, three layers (three adjmatrix), bias set as a vector of same length
    # batch from 50 to 100
    # last hidden size 10 to 20
    # train: 3.33, val: 3.38, test: 3.71
    # train: 3.24, val: 3.31, test: 3.66
    # train: 3.22, val: 3.29, test: 3.66
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, three layers (three adjmatrix), bias set as a vector of same length
    # batch from 50 to 100
    # three hidden size 5, 5, 10
    # train: 3.5, val: 3.48, test: 3.82 
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, three layers (three adjmatrix), bias set as a vector of same length
    # batch from 50 to 100
    # three hidden size 10, 10, 20
    # learning rate: 0.005
    # train: 3.23, val: 3.34, test: 3.74
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, three layers (three adjmatrix), bias set as a vector of same length
    # batch from 50 to 200
    # three hidden size 10, 10, 20
    # learning rate: 0.01
    # shuffle
    # train: 3.19, val: 3.30, test: 3.67
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, three layers (three adjmatrix), bias set as a vector of same length
    # batch from 50 to 100
    # three hidden size 10, 10, 20
    # learning rate: 0.01
    # shuffle
    # train: 3.15, val: 3.26, test: 3.61
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, three layers (three adjmatrix), bias set as a vector of same length
    # batch from 50 to 100
    # three hidden size 10, 10, 20
    # learning rate: 0.01
    # shuffle
    # fully freedom adjacency matrix (not symmetric )
    # train: , val: , test: 
    # training cost around 6.15, not decreasing anymore
    
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, three layers (three adjmatrix), bias set as a vector of same length
    # batch from 50 to 100
    # three hidden size 10, 10, 20
    # learning rate: 0.005
    # change gradient decent algorithm
    # train: 3.19, val: 3.28, test: 3.67

# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, three layers (three adjmatrix), bias set as a vector of same length
    # batch from 50 to 100
    # three hidden size 10, 10, 20
    # learning rate: 0.005
    # change gradient decent algorithm
    # keep: 0.8
    # train: 3.30, val: 3.36, test: 3.78
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, three layers (three adjmatrix), bias set as a vector of same length
    # batch from 50 to 200
    # three hidden size 10, 10, 20
    # learning rate: 0.01
    # change gradient decent algorithm
    # keep: 1
    # train: 3.15, val: 3.27, test: 3.63
    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, three layers (three adjmatrix), bias set as a vector of same length
    # batch from 50 to 200
    # three hidden size 10, 10, 20
    # learning rate: 0.01
    # change gradient decent algorithm
    # keep: 1
    # bias not the same size
    # decreasing slow

    
# increase sample, learning rate to 0.01, batch size is 50, one hidden level, hidden 10, 
    #prediction horizon 12, normalize the data, normalize the symmetric adjacency matrix, 
    # remove "0" ground truths as the paper, three layers (three adjmatrix), bias set as a vector of same length
    # batch size 200
    # second size 10 to 10
    # last hidden size 10 to 30
    # set the same size may lead to indecreasing cost (need to increase batch size)
    # train: 3.05, val: 3.22, test: 3.73

# batch size 150 really slow

# %%
# change hidden number
# change batch_size
# set size
#from bayes_opt import BayesianOptimization
import datetime
#freq_max = 12
#time_step = 12
learning_rate = 0.01
decay = 0.9 
batch_size = 500

early_stop_th = 150
training_epochs = 1000
keep = 1#0.2
#time_step_max = 10

sn = 207 # station num
#test = 2000 
reg1 = 0.05#0.05
reg2 = 0.05#0.1
reg3 = 0.05
frequency = 12
horizon = 12
n_hidden_vec1 = 10
n_hidden_vec2 = 10
n_hidden_vec3 = 20
n_hidden_vec4 = 10
#All_pred = np.empty([2000, 207])
#All_Y = np.empty([2000, 207])

#24*90
#step = 0
#gap = 100
#training = 0.7
#validation = 0.1
#test = 0.2

#gcn_corr_eval(7, 0.01, 0.5, 100, 0.4, 10, 5, 5, 0.2, 50, 500)



rep = 1 # repeating times

#total_sn = 0
#num_iter = 50
#init_points = 200


# stdbscan
#spatial_threshold = 300
#temporal_threshold = 300
#min_neighbors = 1 # number of neighbor

#frequency2 = skip1 + freq_max + training

#while step < 2000:

#hourly_bike_cluster = hourly_bike
best = -10000
pre_best = []
test_Y_best = []
test_error_best = 1000
A1_best = []
# A2_best = []
for i in range(rep):
    a = datetime.datetime.now()
    val_error, predic_res, test_Y,test_error, A1=gcn_corr_final(frequency, horizon, learning_rate, decay, batch_size, n_hidden_vec1,
                                                                n_hidden_vec2, n_hidden_vec3, keep, early_stop_th, training_epochs, reg1, reg2)
    #val_error, predic_res, test_Y,test_error=gcn_corr_final(a['frequency'], a['learning_rate'], a['decay'], a['batch_size'], a['n_hidden_vec1'], a['n_hidden_vec2'], a['n_hidden_vec3'], a['keep'], a['early_stop_th'], a['training_epochs'], a['reg'])
    #print ("finished A running: ", i)
    b = datetime.datetime.now()
    print(b-a)
    if val_error > best:
        best = val_error
        pre_best = predic_res
        test_Y_best = test_Y
        test_error_best = test_error
        #A1_best = A1
       # A2_best = A2

    #val_error, predic_res, test_Y,test_error=gcn_corr_final(24, 0.02, 0.2, 100, 5, 10, 10, 0.8, 50, 500)
    All_pred = pre_best
    All_Y  = test_Y_best

    #total_sn = total_sn + sn

    #total_error = np.sqrt(np.mean((All_pred[0:(step+gap),0:total_sn] - All_Y[0:(step+gap),0:total_sn])**2))

    #print ("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!the cluster now is: ", c)
    #print ("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!the val error of this cluster now is: ", best)
    #print ("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!the test error by this cluster now is: ", total_error)
    #step = step + gap
    #skip1 = skip1 + gap
    
    #np.savetxt("prediction_2.csv", All_pred, delimiter = ',')
    #np.savetxt("prediction_Y_2.csv", All_Y, delimiter = ',')
# Out:
# Epoch: 0001 Training MAE= 40.796289758
# Validation MAE:  21.81255
# Test MAE:  24.837908
# Epoch: 0002 Training MAE= 17.584042571
# Validation MAE:  14.764458
# Test MAE:  16.592161
# Epoch: 0003 Training MAE= 12.936476669
# Validation MAE:  11.127795
# Test MAE:  12.447246
# Epoch: 0004 Training MAE= 9.866238612
# Validation MAE:  9.018043
# Test MAE:  9.9506855
# Epoch: 0005 Training MAE= 8.597576671
# Validation MAE:  8.408047
# Test MAE:  9.161226
# Epoch: 0006 Training MAE= 8.115301197
# Validation MAE:  8.028139
# Test MAE:  8.72552
# Epoch: 0007 Training MAE= 7.876455234
# Validation MAE:  7.823903
# Test MAE:  8.517563
# Epoch: 0008 Training MAE= 7.710261698
# Validation MAE:  7.647564
# Test MAE:  8.340325
# Epoch: 0009 Training MAE= 7.538506482
# Validation MAE:  7.454334
# Test MAE:  8.147812
# Epoch: 0010 Training MAE= 7.345534969
# Validation MAE:  7.2382736
# Test MAE:  7.9328294
# Epoch: 0011 Training MAE= 7.134895619
# Validation MAE:  7.0105867
# Test MAE:  7.699599
# Epoch: 0012 Training MAE= 6.919796831
# Validation MAE:  6.7861905
# Test MAE:  7.4618635
# Epoch: 0013 Training MAE= 6.714176553
# Validation MAE:  6.5845814
# Test MAE:  7.240936
# Epoch: 0014 Training MAE= 6.533429963
# Validation MAE:  6.420172
# Test MAE:  7.0584283
# Epoch: 0015 Training MAE= 6.385766540
# Validation MAE:  6.285642
# Test MAE:  6.9119115
# Epoch: 0016 Training MAE= 6.262707659
# Validation MAE:  6.1699066
# Test MAE:  6.7880473
# Epoch: 0017 Training MAE= 6.155120975
# Validation MAE:  6.065778
# Test MAE:  6.677283
# Epoch: 0018 Training MAE= 6.058586939
# Validation MAE:  5.9709015
# Test MAE:  6.576653
# Epoch: 0019 Training MAE= 5.971074282
# Validation MAE:  5.8841286
# Test MAE:  6.484318
# Epoch: 0020 Training MAE= 5.890779041
# Validation MAE:  5.8040276
# Test MAE:  6.3990216
# Epoch: 0021 Training MAE= 5.815771935
# Validation MAE:  5.7292314
# Test MAE:  6.3190656
# Epoch: 0022 Training MAE= 5.744887579
# Validation MAE:  5.658637
# Test MAE:  6.2427588
# Epoch: 0023 Training MAE= 5.677233298
# Validation MAE:  5.5899396
# Test MAE:  6.168894
# Epoch: 0024 Training MAE= 5.611003274
# Validation MAE:  5.521818
# Test MAE:  6.0952835
# Epoch: 0025 Training MAE= 5.544965035
# Validation MAE:  5.4546704
# Test MAE:  6.0210743
# Epoch: 0026 Training MAE= 5.477672519
# Validation MAE:  5.386586
# Test MAE:  5.9433947
# Epoch: 0027 Training MAE= 5.408058117
# Validation MAE:  5.3181195
# Test MAE:  5.865052
# Epoch: 0028 Training MAE= 5.336196553
# Validation MAE:  5.2518425
# Test MAE:  5.787772
# Epoch: 0029 Training MAE= 5.262477313
# Validation MAE:  5.184229
# Test MAE:  5.707769
# Epoch: 0030 Training MAE= 5.188487430
# Validation MAE:  5.1161566
# Test MAE:  5.6253467
# Epoch: 0031 Training MAE= 5.114702294
# Validation MAE:  5.043818
# Test MAE:  5.5404525
# Epoch: 0032 Training MAE= 5.039574251
# Validation MAE:  4.9684453
# Test MAE:  5.4528217
# Epoch: 0033 Training MAE= 4.963658586
# Validation MAE:  4.8919487
# Test MAE:  5.367086
# Epoch: 0034 Training MAE= 4.890000800
# Validation MAE:  4.8216906
# Test MAE:  5.2875266
# Epoch: 0035 Training MAE= 4.822035949
# Validation MAE:  4.7573423
# Test MAE:  5.215754
# Epoch: 0036 Training MAE= 4.760964949
# Validation MAE:  4.699705
# Test MAE:  5.1528373
# Epoch: 0037 Training MAE= 4.704983740
# Validation MAE:  4.6459455
# Test MAE:  5.0947433
# Epoch: 0038 Training MAE= 4.653686269
# Validation MAE:  4.5978603
# Test MAE:  5.0451107
# Epoch: 0039 Training MAE= 4.606153075
# Validation MAE:  4.5530667
# Test MAE:  4.9992704
# Epoch: 0040 Training MAE= 4.561688786
# Validation MAE:  4.51156
# Test MAE:  4.9565253
# Epoch: 0041 Training MAE= 4.518497629
# Validation MAE:  4.4712057
# Test MAE:  4.9153123
# Epoch: 0042 Training MAE= 4.478184688
# Validation MAE:  4.4346747
# Test MAE:  4.8771296
# Epoch: 0043 Training MAE= 4.438734101
# Validation MAE:  4.3962374
# Test MAE:  4.838862
# Epoch: 0044 Training MAE= 4.399498116
# Validation MAE:  4.3565593
# Test MAE:  4.801809
# Epoch: 0045 Training MAE= 4.360268664
# Validation MAE:  4.3140545
# Test MAE:  4.7627754
# Epoch: 0046 Training MAE= 4.320705466
# Validation MAE:  4.273803
# Test MAE:  4.726827
# Epoch: 0047 Training MAE= 4.280083636
# Validation MAE:  4.229134
# Test MAE:  4.685392
# Epoch: 0048 Training MAE= 4.238016086
# Validation MAE:  4.183927
# Test MAE:  4.6423573
# Epoch: 0049 Training MAE= 4.200190490
# Validation MAE:  4.147433
# Test MAE:  4.6082587
# Epoch: 0050 Training MAE= 4.169364071
# Validation MAE:  4.117816
# Test MAE:  4.580583
# Epoch: 0051 Training MAE= 4.143513454
# Validation MAE:  4.0916576
# Test MAE:  4.555035
# Epoch: 0052 Training MAE= 4.120810655
# Validation MAE:  4.0699296
# Test MAE:  4.5307713
# Epoch: 0053 Training MAE= 4.100531456
# Validation MAE:  4.0495415
# Test MAE:  4.508331
# Epoch: 0054 Training MAE= 4.082213812
# Validation MAE:  4.0317726
# Test MAE:  4.487795
# Epoch: 0055 Training MAE= 4.064747067
# Validation MAE:  4.014367
# Test MAE:  4.467072
# Epoch: 0056 Training MAE= 4.048712336
# Validation MAE:  3.997523
# Test MAE:  4.446566
# Epoch: 0057 Training MAE= 4.033598786
# Validation MAE:  3.9832535
# Test MAE:  4.429329
# Epoch: 0058 Training MAE= 4.019432519
# Validation MAE:  3.968283
# Test MAE:  4.41256
# Epoch: 0059 Training MAE= 4.005770210
# Validation MAE:  3.9547608
# Test MAE:  4.396643
# Epoch: 0060 Training MAE= 3.992547509
# Validation MAE:  3.9407003
# Test MAE:  4.380799
# Epoch: 0061 Training MAE= 3.979363696
# Validation MAE:  3.9271383
# Test MAE:  4.3672457
# Epoch: 0062 Training MAE= 3.967458521
# Validation MAE:  3.9141333
# Test MAE:  4.353532
# Epoch: 0063 Training MAE= 3.956147130
# Validation MAE:  3.9036899
# Test MAE:  4.3430166
# Epoch: 0064 Training MAE= 3.945410842
# Validation MAE:  3.8928995
# Test MAE:  4.3323555
# Epoch: 0065 Training MAE= 3.935383030
# Validation MAE:  3.8836086
# Test MAE:  4.3233833
# Epoch: 0066 Training MAE= 3.926182477
# Validation MAE:  3.8736553
# Test MAE:  4.3143153
# Epoch: 0067 Training MAE= 3.917324653
# Validation MAE:  3.8646128
# Test MAE:  4.305162
# Epoch: 0068 Training MAE= 3.908636341
# Validation MAE:  3.856642
# Test MAE:  4.2969284
# Epoch: 0069 Training MAE= 3.900614453
# Validation MAE:  3.8484066
# Test MAE:  4.2891507
# Epoch: 0070 Training MAE= 3.892250755
# Validation MAE:  3.8400953
# Test MAE:  4.281058
# Epoch: 0071 Training MAE= 3.885100771
# Validation MAE:  3.8322802
# Test MAE:  4.27346
# Epoch: 0072 Training MAE= 3.876919533
# Validation MAE:  3.8252735
# Test MAE:  4.2657104
# Epoch: 0073 Training MAE= 3.870148546
# Validation MAE:  3.818095
# Test MAE:  4.2574925
# Epoch: 0074 Training MAE= 3.862948788
# Validation MAE:  3.8110194
# Test MAE:  4.2497277
# Epoch: 0075 Training MAE= 3.856491312
# Validation MAE:  3.8052268
# Test MAE:  4.243421
# Epoch: 0076 Training MAE= 3.850428159
# Validation MAE:  3.7997417
# Test MAE:  4.2366815
# Epoch: 0077 Training MAE= 3.844070331
# Validation MAE:  3.7953067
# Test MAE:  4.23113
# Epoch: 0078 Training MAE= 3.838951821
# Validation MAE:  3.7896698
# Test MAE:  4.225567
# Epoch: 0079 Training MAE= 3.833259777
# Validation MAE:  3.7847598
# Test MAE:  4.2218375
# Epoch: 0080 Training MAE= 3.828249277
# Validation MAE:  3.779215
# Test MAE:  4.215968
# Epoch: 0081 Training MAE= 3.822557325
# Validation MAE:  3.7755413
# Test MAE:  4.2116737
# Epoch: 0082 Training MAE= 3.817536333
# Validation MAE:  3.769669
# Test MAE:  4.2072597
# Epoch: 0083 Training MAE= 3.812126433
# Validation MAE:  3.7655103
# Test MAE:  4.2023554
# Epoch: 0084 Training MAE= 3.807270357
# Validation MAE:  3.7616563
# Test MAE:  4.197688
# Epoch: 0085 Training MAE= 3.802114679
# Validation MAE:  3.7568955
# Test MAE:  4.1925116
# Epoch: 0086 Training MAE= 3.797377631
# Validation MAE:  3.7535284
# Test MAE:  4.188781
# Epoch: 0087 Training MAE= 3.792549051
# Validation MAE:  3.7480495
# Test MAE:  4.184021
# Epoch: 0088 Training MAE= 3.787655472
# Validation MAE:  3.7438228
# Test MAE:  4.1789045
# Epoch: 0089 Training MAE= 3.782642852
# Validation MAE:  3.7386043
# Test MAE:  4.1737437
# Epoch: 0090 Training MAE= 3.778114402
# Validation MAE:  3.7352073
# Test MAE:  4.17054
# Epoch: 0091 Training MAE= 3.773885045
# Validation MAE:  3.7330387
# Test MAE:  4.167834
# Epoch: 0092 Training MAE= 3.769668139
# Validation MAE:  3.7279353
# Test MAE:  4.163671
# Epoch: 0093 Training MAE= 3.765777505
# Validation MAE:  3.726758
# Test MAE:  4.1623106
# Epoch: 0094 Training MAE= 3.761881348
# Validation MAE:  3.7210557
# Test MAE:  4.157902
# Epoch: 0095 Training MAE= 3.758226492
# Validation MAE:  3.7183447
# Test MAE:  4.1552134
# Epoch: 0096 Training MAE= 3.754630980
# Validation MAE:  3.713476
# Test MAE:  4.151862
# Epoch: 0097 Training MAE= 3.751062921
# Validation MAE:  3.7113123
# Test MAE:  4.14934
# Epoch: 0098 Training MAE= 3.747385698
# Validation MAE:  3.7087917
# Test MAE:  4.1461463
# Epoch: 0099 Training MAE= 3.744275656
# Validation MAE:  3.7058747
# Test MAE:  4.144197
# Epoch: 0100 Training MAE= 3.741345918
# Validation MAE:  3.7037666
# Test MAE:  4.141985
# Epoch: 0101 Training MAE= 3.737850206
# Validation MAE:  3.6989799
# Test MAE:  4.137556
# Epoch: 0102 Training MAE= 3.734863995
# Validation MAE:  3.6956162
# Test MAE:  4.135093
# Epoch: 0103 Training MAE= 3.731902989
# Validation MAE:  3.693461
# Test MAE:  4.131798
# Epoch: 0104 Training MAE= 3.728890916
# Validation MAE:  3.6898158
# Test MAE:  4.1290317
# Epoch: 0105 Training MAE= 3.726203182
# Validation MAE:  3.6875582
# Test MAE:  4.127346
# Epoch: 0106 Training MAE= 3.723055178
# Validation MAE:  3.6848912
# Test MAE:  4.123892
# Epoch: 0107 Training MAE= 3.719911062
# Validation MAE:  3.6810837
# Test MAE:  4.1208687
# Epoch: 0108 Training MAE= 3.717172360
# Validation MAE:  3.6774294
# Test MAE:  4.1172304
# Epoch: 0109 Training MAE= 3.713932310
# Validation MAE:  3.6755316
# Test MAE:  4.1153793
# Epoch: 0110 Training MAE= 3.711011421
# Validation MAE:  3.6704257
# Test MAE:  4.11149
# Epoch: 0111 Training MAE= 3.708139649
# Validation MAE:  3.6699615
# Test MAE:  4.1102705
# Epoch: 0112 Training MAE= 3.705313352
# Validation MAE:  3.6665158
# Test MAE:  4.106819
# Epoch: 0113 Training MAE= 3.702743485
# Validation MAE:  3.6623824
# Test MAE:  4.1028724
# Epoch: 0114 Training MAE= 3.699957158
# Validation MAE:  3.6600606
# Test MAE:  4.100379
# Epoch: 0115 Training MAE= 3.696889234
# Validation MAE:  3.656796
# Test MAE:  4.0969524
# Epoch: 0116 Training MAE= 3.694093453
# Validation MAE:  3.6555161
# Test MAE:  4.095351
# Epoch: 0117 Training MAE= 3.691751158
# Validation MAE:  3.6521916
# Test MAE:  4.0925
# Epoch: 0118 Training MAE= 3.689010680
# Validation MAE:  3.6496336
# Test MAE:  4.089478
# Epoch: 0119 Training MAE= 3.686155065
# Validation MAE:  3.64793
# Test MAE:  4.0879054
# Epoch: 0120 Training MAE= 3.683903296
# Validation MAE:  3.6461642
# Test MAE:  4.085928
# Epoch: 0121 Training MAE= 3.681540241
# Validation MAE:  3.6425128
# Test MAE:  4.083284
# Epoch: 0122 Training MAE= 3.679055464
# Validation MAE:  3.6405325
# Test MAE:  4.0823846
# Epoch: 0123 Training MAE= 3.676563192
# Validation MAE:  3.6385937
# Test MAE:  4.0797033
# Epoch: 0124 Training MAE= 3.674550730
# Validation MAE:  3.6358063
# Test MAE:  4.077681
# Epoch: 0125 Training MAE= 3.672302818
# Validation MAE:  3.6357813
# Test MAE:  4.076699
# Epoch: 0126 Training MAE= 3.670509339
# Validation MAE:  3.6331291
# Test MAE:  4.075371
# Epoch: 0127 Training MAE= 3.668261706
# Validation MAE:  3.6311812
# Test MAE:  4.0736284
# Epoch: 0128 Training MAE= 3.665811956
# Validation MAE:  3.6283114
# Test MAE:  4.0719557
# Epoch: 0129 Training MAE= 3.663975840
# Validation MAE:  3.6272492
# Test MAE:  4.0704637
# Epoch: 0130 Training MAE= 3.662369151
# Validation MAE:  3.624577
# Test MAE:  4.06913
# Epoch: 0131 Training MAE= 3.660007138
# Validation MAE:  3.6230962
# Test MAE:  4.067194
# Epoch: 0132 Training MAE= 3.658128739
# Validation MAE:  3.6215627
# Test MAE:  4.0662622
# Epoch: 0133 Training MAE= 3.656257126
# Validation MAE:  3.6189954
# Test MAE:  4.0642676
# Epoch: 0134 Training MAE= 3.654366400
# Validation MAE:  3.6177905
# Test MAE:  4.062435
# Epoch: 0135 Training MAE= 3.652531459
# Validation MAE:  3.6175127
# Test MAE:  4.0627875
# Epoch: 0136 Training MAE= 3.650661887
# Validation MAE:  3.6144338
# Test MAE:  4.0608864
# Epoch: 0137 Training MAE= 3.648797955
# Validation MAE:  3.6138513
# Test MAE:  4.05986
# Epoch: 0138 Training MAE= 3.647155852
# Validation MAE:  3.611652
# Test MAE:  4.058056
# Epoch: 0139 Training MAE= 3.645678502
# Validation MAE:  3.6097918
# Test MAE:  4.0566397
# Epoch: 0140 Training MAE= 3.643768006
# Validation MAE:  3.610063
# Test MAE:  4.0569515
# Epoch: 0141 Training MAE= 3.642282361
# Validation MAE:  3.6066806
# Test MAE:  4.05284
# Epoch: 0142 Training MAE= 3.640152446
# Validation MAE:  3.6056964
# Test MAE:  4.0536165
# Epoch: 0143 Training MAE= 3.638971132
# Validation MAE:  3.6061
# Test MAE:  4.053502
# Epoch: 0144 Training MAE= 3.637434471
# Validation MAE:  3.603573
# Test MAE:  4.0501986
# Epoch: 0145 Training MAE= 3.635839965
# Validation MAE:  3.6035328
# Test MAE:  4.052242
# Epoch: 0146 Training MAE= 3.634545323
# Validation MAE:  3.600113
# Test MAE:  4.048415
# Epoch: 0147 Training MAE= 3.632775657
# Validation MAE:  3.5982137
# Test MAE:  4.047107
# Epoch: 0148 Training MAE= 3.630886246
# Validation MAE:  3.5978844
# Test MAE:  4.04585
# Epoch: 0149 Training MAE= 3.630035325
# Validation MAE:  3.5976367
# Test MAE:  4.0459642
# Epoch: 0150 Training MAE= 3.628634005
# Validation MAE:  3.5958917
# Test MAE:  4.0440507
# Epoch: 0151 Training MAE= 3.626592224
# Validation MAE:  3.5953324
# Test MAE:  4.044188
# Epoch: 0152 Training MAE= 3.625877212
# Validation MAE:  3.5961757
# Test MAE:  4.0454006
# Epoch: 0153 Training MAE= 3.624409624
# Validation MAE:  3.5926104
# Test MAE:  4.042848
# Epoch: 0154 Training MAE= 3.623088903
# Validation MAE:  3.5893598
# Test MAE:  4.0397797
# Epoch: 0155 Training MAE= 3.621030025
# Validation MAE:  3.589143
# Test MAE:  4.0395145
# Epoch: 0156 Training MAE= 3.620657881
# Validation MAE:  3.5886953
# Test MAE:  4.039477
# Epoch: 0157 Training MAE= 3.618754411
# Validation MAE:  3.5880072
# Test MAE:  4.038395
# Epoch: 0158 Training MAE= 3.618079869
# Validation MAE:  3.58793
# Test MAE:  4.039718
# Epoch: 0159 Training MAE= 3.617276736
# Validation MAE:  3.5876338
# Test MAE:  4.037759
# Epoch: 0160 Training MAE= 3.615366813
# Validation MAE:  3.58616
# Test MAE:  4.0369935
# Epoch: 0161 Training MAE= 3.614767264
# Validation MAE:  3.5824904
# Test MAE:  4.0348153
# Epoch: 0162 Training MAE= 3.613619394
# Validation MAE:  3.5841782
# Test MAE:  4.035413
# Epoch: 0163 Training MAE= 3.612111829
# Validation MAE:  3.5813482
# Test MAE:  4.033243
# Epoch: 0164 Training MAE= 3.610680560
# Validation MAE:  3.5813396
# Test MAE:  4.033255
# Epoch: 0165 Training MAE= 3.609662330
# Validation MAE:  3.5794241
# Test MAE:  4.0317883
# Epoch: 0166 Training MAE= 3.608693647
# Validation MAE:  3.5793226
# Test MAE:  4.031553
# Epoch: 0167 Training MAE= 3.607239493
# Validation MAE:  3.5772862
# Test MAE:  4.030961
# Epoch: 0168 Training MAE= 3.605282177
# Validation MAE:  3.575629
# Test MAE:  4.0295286
# Epoch: 0169 Training MAE= 3.604634844
# Validation MAE:  3.5769718
# Test MAE:  4.030155
# Epoch: 0170 Training MAE= 3.603391300
# Validation MAE:  3.5756617
# Test MAE:  4.0288043
# Epoch: 0171 Training MAE= 3.601699029
# Validation MAE:  3.5735748
# Test MAE:  4.0272484
# Epoch: 0172 Training MAE= 3.600347943
# Validation MAE:  3.573637
# Test MAE:  4.0277743
# Epoch: 0173 Training MAE= 3.599187775
# Validation MAE:  3.5717351
# Test MAE:  4.026831
# Epoch: 0174 Training MAE= 3.598238493
# Validation MAE:  3.571935
# Test MAE:  4.0266514
# Epoch: 0175 Training MAE= 3.597373264
# Validation MAE:  3.5717978
# Test MAE:  4.026911
# Epoch: 0176 Training MAE= 3.595625128
# Validation MAE:  3.5706475
# Test MAE:  4.025274
# Epoch: 0177 Training MAE= 3.594731481
# Validation MAE:  3.5710301
# Test MAE:  4.0248995
# Epoch: 0178 Training MAE= 3.593878659
# Validation MAE:  3.56777
# Test MAE:  4.023086
# Epoch: 0179 Training MAE= 3.592334676
# Validation MAE:  3.5675404
# Test MAE:  4.0239305
# Epoch: 0180 Training MAE= 3.591287366
# Validation MAE:  3.5666513
# Test MAE:  4.0226846
# Epoch: 0181 Training MAE= 3.589656335
# Validation MAE:  3.564345
# Test MAE:  4.0222244
# Epoch: 0182 Training MAE= 3.589020835
# Validation MAE:  3.5652275
# Test MAE:  4.0221167
# Epoch: 0183 Training MAE= 3.590254835
# Validation MAE:  3.5646358
# Test MAE:  4.0234294
# Epoch: 0184 Training MAE= 3.587276995
# Validation MAE:  3.5618334
# Test MAE:  4.0197983
# Epoch: 0185 Training MAE= 3.584932376
# Validation MAE:  3.5596173
# Test MAE:  4.0190086
# Epoch: 0186 Training MAE= 3.584220747
# Validation MAE:  3.5603263
# Test MAE:  4.0185056
# Epoch: 0187 Training MAE= 3.583389787
# Validation MAE:  3.5591671
# Test MAE:  4.01753
# Epoch: 0188 Training MAE= 3.583154161
# Validation MAE:  3.557243
# Test MAE:  4.0180545
# Epoch: 0189 Training MAE= 3.582222474
# Validation MAE:  3.5573583
# Test MAE:  4.017387
# Epoch: 0190 Training MAE= 3.580386374
# Validation MAE:  3.555015
# Test MAE:  4.0168076
# Epoch: 0191 Training MAE= 3.579294180
# Validation MAE:  3.5552561
# Test MAE:  4.0156846
# Epoch: 0192 Training MAE= 3.579097552
# Validation MAE:  3.5533152
# Test MAE:  4.0153913
# Epoch: 0193 Training MAE= 3.577804725
# Validation MAE:  3.552871
# Test MAE:  4.016023
# Epoch: 0194 Training MAE= 3.577264460
# Validation MAE:  3.552632
# Test MAE:  4.0158668
# Epoch: 0195 Training MAE= 3.577278203
# Validation MAE:  3.5523937
# Test MAE:  4.016185
# Epoch: 0196 Training MAE= 3.575483944
# Validation MAE:  3.5503786
# Test MAE:  4.014879
# Epoch: 0197 Training MAE= 3.574224256
# Validation MAE:  3.5486705
# Test MAE:  4.014293
# Epoch: 0198 Training MAE= 3.574593857
# Validation MAE:  3.5508769
# Test MAE:  4.016794
# Epoch: 0199 Training MAE= 3.573066424
# Validation MAE:  3.5491097
# Test MAE:  4.015642
# Epoch: 0200 Training MAE= 3.571635621
# Validation MAE:  3.5477872
# Test MAE:  4.0143414
# Epoch: 0201 Training MAE= 3.571006487
# Validation MAE:  3.5473447
# Test MAE:  4.0141463
# Epoch: 0202 Training MAE= 3.570598683
# Validation MAE:  3.5459807
# Test MAE:  4.0139737
# Epoch: 0203 Training MAE= 3.568973996
# Validation MAE:  3.544799
# Test MAE:  4.013453
# Epoch: 0204 Training MAE= 3.569465210
# Validation MAE:  3.5483212
# Test MAE:  4.0157247
# Epoch: 0205 Training MAE= 3.568242653
# Validation MAE:  3.5430486
# Test MAE:  4.013691
# Epoch: 0206 Training MAE= 3.565748087
# Validation MAE:  3.5415113
# Test MAE:  4.012271
# Epoch: 0207 Training MAE= 3.565266041
# Validation MAE:  3.5417063
# Test MAE:  4.0126886
# Epoch: 0208 Training MAE= 3.564911357
# Validation MAE:  3.5397525
# Test MAE:  4.012994
# Epoch: 0209 Training MAE= 3.563607761
# Validation MAE:  3.5407286
# Test MAE:  4.013033
# Epoch: 0210 Training MAE= 3.563144364
# Validation MAE:  3.5412376
# Test MAE:  4.0129666
# Epoch: 0211 Training MAE= 3.562789201
# Validation MAE:  3.5408847
# Test MAE:  4.0136557
# Epoch: 0212 Training MAE= 3.561606469
# Validation MAE:  3.5387528
# Test MAE:  4.0122337
# Epoch: 0213 Training MAE= 3.560957637
# Validation MAE:  3.5374472
# Test MAE:  4.01148
# Epoch: 0214 Training MAE= 3.560348934
# Validation MAE:  3.537832
# Test MAE:  4.0112357
# Epoch: 0215 Training MAE= 3.559548470
# Validation MAE:  3.5348072
# Test MAE:  4.011025
# Epoch: 0216 Training MAE= 3.558568531
# Validation MAE:  3.5348792
# Test MAE:  4.011324
# Epoch: 0217 Training MAE= 3.557702860
# Validation MAE:  3.5345368
# Test MAE:  4.0101733
# Epoch: 0218 Training MAE= 3.556808723
# Validation MAE:  3.5329826
# Test MAE:  4.0101995
# Epoch: 0219 Training MAE= 3.556428105
# Validation MAE:  3.5347664
# Test MAE:  4.0109086
# Epoch: 0220 Training MAE= 3.556084761
# Validation MAE:  3.5324104
# Test MAE:  4.008973
# Epoch: 0221 Training MAE= 3.554931373
# Validation MAE:  3.5348468
# Test MAE:  4.01073
# Epoch: 0222 Training MAE= 3.554752427
# Validation MAE:  3.5306716
# Test MAE:  4.0093155
# Epoch: 0223 Training MAE= 3.554297368
# Validation MAE:  3.53211
# Test MAE:  4.0104666
# Epoch: 0224 Training MAE= 3.553496025
# Validation MAE:  3.5289986
# Test MAE:  4.0078893
# Epoch: 0225 Training MAE= 3.552248000
# Validation MAE:  3.5302732
# Test MAE:  4.0075526
# Epoch: 0226 Training MAE= 3.552086978
# Validation MAE:  3.5287063
# Test MAE:  4.0074563
# Epoch: 0227 Training MAE= 3.551269584
# Validation MAE:  3.5279658
# Test MAE:  4.007766
# Epoch: 0228 Training MAE= 3.550417418
# Validation MAE:  3.5275161
# Test MAE:  4.00747
# Epoch: 0229 Training MAE= 3.548936122
# Validation MAE:  3.5262508
# Test MAE:  4.006124
# Epoch: 0230 Training MAE= 3.548904908
# Validation MAE:  3.5261898
# Test MAE:  4.0066614
# Epoch: 0231 Training MAE= 3.548621724
# Validation MAE:  3.5257313
# Test MAE:  4.005759
# Epoch: 0232 Training MAE= 3.547250571
# Validation MAE:  3.5243247
# Test MAE:  4.0057425
# Epoch: 0233 Training MAE= 3.547403800
# Validation MAE:  3.5251253
# Test MAE:  4.006926
# Epoch: 0234 Training MAE= 3.545648163
# Validation MAE:  3.5225685
# Test MAE:  4.004791
# Epoch: 0235 Training MAE= 3.545703182
# Validation MAE:  3.523724
# Test MAE:  4.0052996
# Epoch: 0236 Training MAE= 3.544836426
# Validation MAE:  3.5226033
# Test MAE:  4.003863
# Epoch: 0237 Training MAE= 3.544673500
# Validation MAE:  3.5223036
# Test MAE:  4.005711
# Epoch: 0238 Training MAE= 3.543147553
# Validation MAE:  3.5208955
# Test MAE:  4.0028887
# Epoch: 0239 Training MAE= 3.542718510
# Validation MAE:  3.520858
# Test MAE:  4.0028
# Epoch: 0240 Training MAE= 3.542243293
# Validation MAE:  3.5204985
# Test MAE:  4.0031624
# Epoch: 0241 Training MAE= 3.541535338
# Validation MAE:  3.5196016
# Test MAE:  4.0026197
# Epoch: 0242 Training MAE= 3.541152793
# Validation MAE:  3.5182931
# Test MAE:  4.0020146
# Epoch: 0243 Training MAE= 3.539715448
# Validation MAE:  3.5172844
# Test MAE:  3.999801
# Epoch: 0244 Training MAE= 3.539374531
# Validation MAE:  3.517179
# Test MAE:  4.0000525
# Epoch: 0245 Training MAE= 3.538965076
# Validation MAE:  3.5171442
# Test MAE:  4.000329
# Epoch: 0246 Training MAE= 3.538010211
# Validation MAE:  3.515425
# Test MAE:  3.9991465
# Epoch: 0247 Training MAE= 3.537088372
# Validation MAE:  3.51562
# Test MAE:  3.9992878
# Epoch: 0248 Training MAE= 3.537394009
# Validation MAE:  3.5149057
# Test MAE:  3.9999692
# Epoch: 0249 Training MAE= 3.537068425
# Validation MAE:  3.5180244
# Test MAE:  4.0022554
# Epoch: 0250 Training MAE= 3.535891872
# Validation MAE:  3.513893
# Test MAE:  3.9985754
# Epoch: 0251 Training MAE= 3.534614137
# Validation MAE:  3.514004
# Test MAE:  3.997774
# Epoch: 0252 Training MAE= 3.534165132
# Validation MAE:  3.5140064
# Test MAE:  3.9986236
# Epoch: 0253 Training MAE= 3.533661932
# Validation MAE:  3.5141892
# Test MAE:  3.997666
# Epoch: 0254 Training MAE= 3.533505083
# Validation MAE:  3.5133157
# Test MAE:  3.9963684
# Epoch: 0255 Training MAE= 3.532531938
# Validation MAE:  3.5122476
# Test MAE:  3.9978552
# Epoch: 0256 Training MAE= 3.532110732
# Validation MAE:  3.5137866
# Test MAE:  3.9975884
# Epoch: 0257 Training MAE= 3.530881782
# Validation MAE:  3.5116825
# Test MAE:  3.9960024
# Epoch: 0258 Training MAE= 3.529399550
# Validation MAE:  3.511712
# Test MAE:  3.994827
# Epoch: 0259 Training MAE= 3.528933816
# Validation MAE:  3.5110903
# Test MAE:  3.9954247
# Epoch: 0260 Training MAE= 3.528536135
# Validation MAE:  3.5116658
# Test MAE:  3.9945407
# Epoch: 0261 Training MAE= 3.528100659
# Validation MAE:  3.5106604
# Test MAE:  3.9938781
# Epoch: 0262 Training MAE= 3.527677015
# Validation MAE:  3.510891
# Test MAE:  3.995467
# Epoch: 0263 Training MAE= 3.526840563
# Validation MAE:  3.5119915
# Test MAE:  3.995938
# Epoch: 0264 Training MAE= 3.526254409
# Validation MAE:  3.5083978
# Test MAE:  3.993013
# Epoch: 0265 Training MAE= 3.524949999
# Validation MAE:  3.5112925
# Test MAE:  3.9947147
# Epoch: 0266 Training MAE= 3.524956958
# Validation MAE:  3.508921
# Test MAE:  3.9939013
# Epoch: 0267 Training MAE= 3.524293996
# Validation MAE:  3.5067961
# Test MAE:  3.990537
# Epoch: 0268 Training MAE= 3.522702167
# Validation MAE:  3.5097082
# Test MAE:  3.99398
# Epoch: 0269 Training MAE= 3.522826268
# Validation MAE:  3.5083444
# Test MAE:  3.9932058
# Epoch: 0270 Training MAE= 3.522116187
# Validation MAE:  3.5079036
# Test MAE:  3.9927561
# Epoch: 0271 Training MAE= 3.521139294
# Validation MAE:  3.507154
# Test MAE:  3.991697
# Epoch: 0272 Training MAE= 3.520407338
# Validation MAE:  3.505615
# Test MAE:  3.9922998
# Epoch: 0273 Training MAE= 3.520151875
# Validation MAE:  3.508867
# Test MAE:  3.9936712
# Epoch: 0274 Training MAE= 3.519490206
# Validation MAE:  3.504738
# Test MAE:  3.989149
# Epoch: 0275 Training MAE= 3.518098277
# Validation MAE:  3.5051544
# Test MAE:  3.9904866
# Epoch: 0276 Training MAE= 3.517716153
# Validation MAE:  3.502248
# Test MAE:  3.98572
# Epoch: 0277 Training MAE= 3.517015091
# Validation MAE:  3.5053904
# Test MAE:  3.9880793
# Epoch: 0278 Training MAE= 3.516288974
# Validation MAE:  3.5028718
# Test MAE:  3.9862776
# Epoch: 0279 Training MAE= 3.515574698
# Validation MAE:  3.503922
# Test MAE:  3.9886467
# Epoch: 0280 Training MAE= 3.515308912
# Validation MAE:  3.503822
# Test MAE:  3.9880412
# Epoch: 0281 Training MAE= 3.514479396
# Validation MAE:  3.5025246
# Test MAE:  3.9864337
# Epoch: 0282 Training MAE= 3.514066070
# Validation MAE:  3.5062647
# Test MAE:  3.990118
# Epoch: 0283 Training MAE= 3.513214656
# Validation MAE:  3.5040991
# Test MAE:  3.988823
# Epoch: 0284 Training MAE= 3.512569156
# Validation MAE:  3.5026371
# Test MAE:  3.986669
# Epoch: 0285 Training MAE= 3.511914397
# Validation MAE:  3.5022104
# Test MAE:  3.9870746
# Epoch: 0286 Training MAE= 3.511237307
# Validation MAE:  3.5031984
# Test MAE:  3.9874332
# Epoch: 0287 Training MAE= 3.510653604
# Validation MAE:  3.5016232
# Test MAE:  3.9865422
# Epoch: 0288 Training MAE= 3.510141802
# Validation MAE:  3.5035424
# Test MAE:  3.9872265
# Epoch: 0289 Training MAE= 3.509901448
# Validation MAE:  3.5027373
# Test MAE:  3.9872105
# Epoch: 0290 Training MAE= 3.508613710
# Validation MAE:  3.5007746
# Test MAE:  3.985933
# Epoch: 0291 Training MAE= 3.508217027
# Validation MAE:  3.5032055
# Test MAE:  3.9867418
# Epoch: 0292 Training MAE= 3.507687150
# Validation MAE:  3.5031075
# Test MAE:  3.986733
# Epoch: 0293 Training MAE= 3.507166737
# Validation MAE:  3.5049434
# Test MAE:  3.9902468
# Epoch: 0294 Training MAE= 3.506240579
# Validation MAE:  3.501197
# Test MAE:  3.9861922
# Epoch: 0295 Training MAE= 3.505537515
# Validation MAE:  3.5017128
# Test MAE:  3.984401
# Epoch: 0296 Training MAE= 3.505023727
# Validation MAE:  3.5035262
# Test MAE:  3.9893222
# Epoch: 0297 Training MAE= 3.504743561
# Validation MAE:  3.5005503
# Test MAE:  3.9858088
# Epoch: 0298 Training MAE= 3.504052911
# Validation MAE:  3.5004425
# Test MAE:  3.9862523
# Epoch: 0299 Training MAE= 3.503569939
# Validation MAE:  3.5026953
# Test MAE:  3.9885366
# Epoch: 0300 Training MAE= 3.503029789
# Validation MAE:  3.5012383
# Test MAE:  3.9869454
# Epoch: 0301 Training MAE= 3.503047547
# Validation MAE:  3.5024352
# Test MAE:  3.988044
# Epoch: 0302 Training MAE= 3.501188687
# Validation MAE:  3.5005298
# Test MAE:  3.9864154
# Epoch: 0303 Training MAE= 3.500748533
# Validation MAE:  3.4998527
# Test MAE:  3.9870982
# Epoch: 0304 Training MAE= 3.501137468
# Validation MAE:  3.5005817
# Test MAE:  3.988704
# Epoch: 0305 Training MAE= 3.500270939
# Validation MAE:  3.5016687
# Test MAE:  3.989429
# Epoch: 0306 Training MAE= 3.499164625
# Validation MAE:  3.4969494
# Test MAE:  3.9856393
# Epoch: 0307 Training MAE= 3.499014590
# Validation MAE:  3.501914
# Test MAE:  3.9898274
# Epoch: 0308 Training MAE= 3.498091123
# Validation MAE:  3.496664
# Test MAE:  3.9861956
# Epoch: 0309 Training MAE= 3.497515446
# Validation MAE:  3.4953988
# Test MAE:  3.9843442
# Epoch: 0310 Training MAE= 3.497718971
# Validation MAE:  3.4995213
# Test MAE:  3.9882557
# Epoch: 0311 Training MAE= 3.496488391
# Validation MAE:  3.4929109
# Test MAE:  3.9838672
# Epoch: 0312 Training MAE= 3.495732037
# Validation MAE:  3.4976537
# Test MAE:  3.987727
# Epoch: 0313 Training MAE= 3.495668776
# Validation MAE:  3.4940917
# Test MAE:  3.985779
# Epoch: 0314 Training MAE= 3.493592458
# Validation MAE:  3.4848661
# Test MAE:  3.9775558
# Epoch: 0315 Training MAE= 3.493246072
# Validation MAE:  3.484844
# Test MAE:  3.978644
# Epoch: 0316 Training MAE= 3.492900393
# Validation MAE:  3.487765
# Test MAE:  3.9817843
# Epoch: 0317 Training MAE= 3.493379995
# Validation MAE:  3.488131
# Test MAE:  3.9811704
# Epoch: 0318 Training MAE= 3.494144900
# Validation MAE:  3.4926443
# Test MAE:  3.9869626
# Epoch: 0319 Training MAE= 3.493337146
# Validation MAE:  3.4934008
# Test MAE:  3.9858363
# Epoch: 0320 Training MAE= 3.492773791
# Validation MAE:  3.4923136
# Test MAE:  3.9856455
# Epoch: 0321 Training MAE= 3.492397750
# Validation MAE:  3.49237
# Test MAE:  3.9877
# Epoch: 0322 Training MAE= 3.492590537
# Validation MAE:  3.4977388
# Test MAE:  3.990619
# Epoch: 0323 Training MAE= 3.491550174
# Validation MAE:  3.4968686
# Test MAE:  3.9880817
# Epoch: 0324 Training MAE= 3.490483284
# Validation MAE:  3.489908
# Test MAE:  3.984073
# Epoch: 0325 Training MAE= 3.488948457
# Validation MAE:  3.487273
# Test MAE:  3.9816368
# Epoch: 0326 Training MAE= 3.489382509
# Validation MAE:  3.497214
# Test MAE:  3.9913137
# Epoch: 0327 Training MAE= 3.489333244
# Validation MAE:  3.4921477
# Test MAE:  3.986153
# Epoch: 0328 Training MAE= 3.488291270
# Validation MAE:  3.4981365
# Test MAE:  3.9903412
# Epoch: 0329 Training MAE= 3.488381057
# Validation MAE:  3.497716
# Test MAE:  3.9915485
# Epoch: 0330 Training MAE= 3.488367932
# Validation MAE:  3.5004728
# Test MAE:  3.9926152
# Epoch: 0331 Training MAE= 3.486615963
# Validation MAE:  3.4874701
# Test MAE:  3.9832413
# Epoch: 0332 Training MAE= 3.486547351
# Validation MAE:  3.5017061
# Test MAE:  3.9943035
# Epoch: 0333 Training MAE= 3.487412065
# Validation MAE:  3.5003152
# Test MAE:  3.994156
# Epoch: 0334 Training MAE= 3.486261016
# Validation MAE:  3.496095
# Test MAE:  3.9919205
# Epoch: 0335 Training MAE= 3.485015390
# Validation MAE:  3.4979985
# Test MAE:  3.9917953
# Epoch: 0336 Training MAE= 3.484770160
# Validation MAE:  3.4992294
# Test MAE:  3.9926913
# Epoch: 0337 Training MAE= 3.483449111
# Validation MAE:  3.492515
# Test MAE:  3.9860811
# Epoch: 0338 Training MAE= 3.482134408
# Validation MAE:  3.486995
# Test MAE:  3.9833443
# Epoch: 0339 Training MAE= 3.482433940
# Validation MAE:  3.493554
# Test MAE:  3.9892771
# Epoch: 0340 Training MAE= 3.483774861
# Validation MAE:  3.504657
# Test MAE:  3.9980907
# Epoch: 0341 Training MAE= 3.484147281
# Validation MAE:  3.4977582
# Test MAE:  3.9935894
# Epoch: 0342 Training MAE= 3.482042643
# Validation MAE:  3.4973083
# Test MAE:  3.9925036
# Epoch: 0343 Training MAE= 3.481219340
# Validation MAE:  3.4950914
# Test MAE:  3.9914029
# Epoch: 0344 Training MAE= 3.482119545
# Validation MAE:  3.5027854
# Test MAE:  3.996601
# Epoch: 0345 Training MAE= 3.480293876
# Validation MAE:  3.491419
# Test MAE:  3.9885015
# Epoch: 0346 Training MAE= 3.478883663
# Validation MAE:  3.4934614
# Test MAE:  3.9902377
# Epoch: 0347 Training MAE= 3.479829731
# Validation MAE:  3.496647
# Test MAE:  3.9926429
# Epoch: 0348 Training MAE= 3.479815844
# Validation MAE:  3.4984038
# Test MAE:  3.9950027
# Epoch: 0349 Training MAE= 3.479606802
# Validation MAE:  3.4955304
# Test MAE:  3.9918084
# Epoch: 0350 Training MAE= 3.478253765
# Validation MAE:  3.4975767
# Test MAE:  3.9945557
# Epoch: 0351 Training MAE= 3.478276417
# Validation MAE:  3.4917154
# Test MAE:  3.9887674
# Epoch: 0352 Training MAE= 3.476531303
# Validation MAE:  3.4929368
# Test MAE:  3.989034
# Epoch: 0353 Training MAE= 3.477207410
# Validation MAE:  3.4952307
# Test MAE:  3.9928465
# Epoch: 0354 Training MAE= 3.476327856
# Validation MAE:  3.4932916
# Test MAE:  3.9919462
# Epoch: 0355 Training MAE= 3.476160330
# Validation MAE:  3.4946434
# Test MAE:  3.9926891
# Epoch: 0356 Training MAE= 3.476166817
# Validation MAE:  3.4958692
# Test MAE:  3.9937978
# Epoch: 0357 Training MAE= 3.477088261
# Validation MAE:  3.4999473
# Test MAE:  3.9977815
# Epoch: 0358 Training MAE= 3.476085130
# Validation MAE:  3.49229
# Test MAE:  3.9917598
# Epoch: 0359 Training MAE= 3.473613467
# Validation MAE:  3.4913204
# Test MAE:  3.9907928
# Epoch: 0360 Training MAE= 3.473497052
# Validation MAE:  3.4890897
# Test MAE:  3.9882739
# Epoch: 0361 Training MAE= 3.473454162
# Validation MAE:  3.4922597
# Test MAE:  3.9917927
# Epoch: 0362 Training MAE= 3.475095358
# Validation MAE:  3.483882
# Test MAE:  3.9830806
# Epoch: 0363 Training MAE= 3.472652750
# Validation MAE:  3.4876294
# Test MAE:  3.9867692
# Epoch: 0364 Training MAE= 3.472347007
# Validation MAE:  3.4866204
# Test MAE:  3.986559
# Epoch: 0365 Training MAE= 3.470780772
# Validation MAE:  3.4816287
# Test MAE:  3.9842346
# Epoch: 0366 Training MAE= 3.471268030
# Validation MAE:  3.4855177
# Test MAE:  3.9868515
# Epoch: 0367 Training MAE= 3.471629317
# Validation MAE:  3.4818094
# Test MAE:  3.9841053
# Epoch: 0368 Training MAE= 3.470888286
# Validation MAE:  3.481806
# Test MAE:  3.9827962
# Epoch: 0369 Training MAE= 3.470392333
# Validation MAE:  3.4747252
# Test MAE:  3.9778073
# Epoch: 0370 Training MAE= 3.468052340
# Validation MAE:  3.480715
# Test MAE:  3.9842958
# Epoch: 0371 Training MAE= 3.469910955
# Validation MAE:  3.476792
# Test MAE:  3.9794135
# Epoch: 0372 Training MAE= 3.468858494
# Validation MAE:  3.4793472
# Test MAE:  3.984363
# Epoch: 0373 Training MAE= 3.468104397
# Validation MAE:  3.476691
# Test MAE:  3.980352
# Epoch: 0374 Training MAE= 3.466497443
# Validation MAE:  3.4785044
# Test MAE:  3.9817166
# Epoch: 0375 Training MAE= 3.467874786
# Validation MAE:  3.480139
# Test MAE:  3.9838433
# Epoch: 0376 Training MAE= 3.467126400
# Validation MAE:  3.4818127
# Test MAE:  3.986804
# Epoch: 0377 Training MAE= 3.468257418
# Validation MAE:  3.4809813
# Test MAE:  3.9848847
# Epoch: 0378 Training MAE= 3.466620281
# Validation MAE:  3.4781988
# Test MAE:  3.9841485
# Epoch: 0379 Training MAE= 3.466199702
# Validation MAE:  3.479465
# Test MAE:  3.9837217
# Epoch: 0380 Training MAE= 3.465810458
# Validation MAE:  3.4769092
# Test MAE:  3.9823074
# Epoch: 0381 Training MAE= 3.465495837
# Validation MAE:  3.4770312
# Test MAE:  3.98079
# Epoch: 0382 Training MAE= 3.464373822
# Validation MAE:  3.4747937
# Test MAE:  3.979401
# Epoch: 0383 Training MAE= 3.463270448
# Validation MAE:  3.474927
# Test MAE:  3.9814126
# Epoch: 0384 Training MAE= 3.463110923
# Validation MAE:  3.4718442
# Test MAE:  3.976739
# Epoch: 0385 Training MAE= 3.463570882
# Validation MAE:  3.4811485
# Test MAE:  3.9858503
# Epoch: 0386 Training MAE= 3.463196638
# Validation MAE:  3.4729614
# Test MAE:  3.980572
# Epoch: 0387 Training MAE= 3.462798184
# Validation MAE:  3.4774632
# Test MAE:  3.9828765
# Epoch: 0388 Training MAE= 3.461996632
# Validation MAE:  3.471075
# Test MAE:  3.9773548
# Epoch: 0389 Training MAE= 3.462116224
# Validation MAE:  3.4772189
# Test MAE:  3.9838157
# Epoch: 0390 Training MAE= 3.460746301
# Validation MAE:  3.4597404
# Test MAE:  3.9676528
# Epoch: 0391 Training MAE= 3.460592531
# Validation MAE:  3.475831
# Test MAE:  3.9837952
# Epoch: 0392 Training MAE= 3.460027699
# Validation MAE:  3.4533
# Test MAE:  3.9624798
# Epoch: 0393 Training MAE= 3.459292214
# Validation MAE:  3.4700708
# Test MAE:  3.9786432
# Epoch: 0394 Training MAE= 3.459677807
# Validation MAE:  3.4585993
# Test MAE:  3.9681275
# Epoch: 0395 Training MAE= 3.459519355
# Validation MAE:  3.4765067
# Test MAE:  3.983172
# Epoch: 0396 Training MAE= 3.459513781
# Validation MAE:  3.456884
# Test MAE:  3.9673088
# Epoch: 0397 Training MAE= 3.459408629
# Validation MAE:  3.4765828
# Test MAE:  3.9837642
# Epoch: 0398 Training MAE= 3.459389655
# Validation MAE:  3.4648306
# Test MAE:  3.9733233
# Epoch: 0399 Training MAE= 3.458983531
# Validation MAE:  3.4771595
# Test MAE:  3.982962
# Epoch: 0400 Training MAE= 3.458081974
# Validation MAE:  3.4616444
# Test MAE:  3.9690778
# Epoch: 0401 Training MAE= 3.457602953
# Validation MAE:  3.4762464
# Test MAE:  3.9846942
# Epoch: 0402 Training MAE= 3.457910160
# Validation MAE:  3.4613917
# Test MAE:  3.9689746
# Epoch: 0403 Training MAE= 3.457788331
# Validation MAE:  3.480702
# Test MAE:  3.9889507
# Epoch: 0404 Training MAE= 3.457494378
# Validation MAE:  3.4606957
# Test MAE:  3.969744
# Epoch: 0405 Training MAE= 3.456835451
# Validation MAE:  3.4754593
# Test MAE:  3.9832158
# Epoch: 0406 Training MAE= 3.455487824
# Validation MAE:  3.449626
# Test MAE:  3.960023
# Epoch: 0407 Training MAE= 3.453646573
# Validation MAE:  3.4551322
# Test MAE:  3.9658542
# Epoch: 0408 Training MAE= 3.454825523
# Validation MAE:  3.4541173
# Test MAE:  3.9646366
# Epoch: 0409 Training MAE= 3.457111991
# Validation MAE:  3.4800222
# Test MAE:  3.9905884
# Epoch: 0410 Training MAE= 3.457869412
# Validation MAE:  3.4780076
# Test MAE:  3.9862545
# Epoch: 0411 Training MAE= 3.454418714
# Validation MAE:  3.451324
# Test MAE:  3.9625113
# Epoch: 0412 Training MAE= 3.453188769
# Validation MAE:  3.4695923
# Test MAE:  3.9811199
# Epoch: 0413 Training MAE= 3.453637546
# Validation MAE:  3.4539988
# Test MAE:  3.963675
# Epoch: 0414 Training MAE= 3.452148161
# Validation MAE:  3.4629302
# Test MAE:  3.9732134
# Epoch: 0415 Training MAE= 3.454779866
# Validation MAE:  3.476305
# Test MAE:  3.9879308
# Epoch: 0416 Training MAE= 3.456487701
# Validation MAE:  3.4827673
# Test MAE:  3.9926257
# Epoch: 0417 Training MAE= 3.453544962
# Validation MAE:  3.4578881
# Test MAE:  3.9699743
# Epoch: 0418 Training MAE= 3.451852624
# Validation MAE:  3.4701006
# Test MAE:  3.9808304
# Epoch: 0419 Training MAE= 3.451788676
# Validation MAE:  3.46098
# Test MAE:  3.972329
# Epoch: 0420 Training MAE= 3.452666494
# Validation MAE:  3.4806943
# Test MAE:  3.9908884
# Epoch: 0421 Training MAE= 3.451515571
# Validation MAE:  3.4652748
# Test MAE:  3.9766307
# Epoch: 0422 Training MAE= 3.450927566
# Validation MAE:  3.4692535
# Test MAE:  3.9818017
# Epoch: 0423 Training MAE= 3.449551819
# Validation MAE:  3.4618018
# Test MAE:  3.9734583
# Epoch: 0424 Training MAE= 3.448566293
# Validation MAE:  3.4600632
# Test MAE:  3.9726706
# Epoch: 0425 Training MAE= 3.449984447
# Validation MAE:  3.4722652
# Test MAE:  3.9865668
# Epoch: 0426 Training MAE= 3.449280646
# Validation MAE:  3.4556994
# Test MAE:  3.9672275
# Epoch: 0427 Training MAE= 3.449025128
# Validation MAE:  3.4734719
# Test MAE:  3.9855578
# Epoch: 0428 Training MAE= 3.448471066
# Validation MAE:  3.4610732
# Test MAE:  3.9722388
# Epoch: 0429 Training MAE= 3.448194565
# Validation MAE:  3.4664912
# Test MAE:  3.9808185
# Epoch: 0430 Training MAE= 3.447001952
# Validation MAE:  3.4542565
# Test MAE:  3.9683409
# Epoch: 0431 Training MAE= 3.447229513
# Validation MAE:  3.4674928
# Test MAE:  3.9796128
# Epoch: 0432 Training MAE= 3.448677265
# Validation MAE:  3.4613695
# Test MAE:  3.975871
# Epoch: 0433 Training MAE= 3.448105665
# Validation MAE:  3.468628
# Test MAE:  3.9805293
# Epoch: 0434 Training MAE= 3.445119932
# Validation MAE:  3.4375563
# Test MAE:  3.9520419
# Epoch: 0435 Training MAE= 3.444864043
# Validation MAE:  3.4563026
# Test MAE:  3.9701936
# Epoch: 0436 Training MAE= 3.445204318
# Validation MAE:  3.4470086
# Test MAE:  3.9625132
# Epoch: 0437 Training MAE= 3.446929275
# Validation MAE:  3.4746175
# Test MAE:  3.9880946
# Epoch: 0438 Training MAE= 3.445851716
# Validation MAE:  3.4382682
# Test MAE:  3.9547067
# Epoch: 0439 Training MAE= 3.442911667
# Validation MAE:  3.4506528
# Test MAE:  3.96561
# Epoch: 0440 Training MAE= 3.443895847
# Validation MAE:  3.4513063
# Test MAE:  3.9659643
# Epoch: 0441 Training MAE= 3.447182858
# Validation MAE:  3.4789548
# Test MAE:  3.9933178
# Epoch: 0442 Training MAE= 3.445598284
# Validation MAE:  3.44948
# Test MAE:  3.9646924
# Epoch: 0443 Training MAE= 3.444201513
# Validation MAE:  3.4650347
# Test MAE:  3.980656
# Epoch: 0444 Training MAE= 3.443969849
# Validation MAE:  3.453805
# Test MAE:  3.9682586
# Epoch: 0445 Training MAE= 3.442966631
# Validation MAE:  3.4591334
# Test MAE:  3.9741197
# Epoch: 0446 Training MAE= 3.442322776
# Validation MAE:  3.452269
# Test MAE:  3.9663808
# Epoch: 0447 Training MAE= 3.444151492
# Validation MAE:  3.4745998
# Test MAE:  3.9891639
# Epoch: 0448 Training MAE= 3.444622319
# Validation MAE:  3.4533005
# Test MAE:  3.9702797
# Epoch: 0449 Training MAE= 3.441362954
# Validation MAE:  3.4573593
# Test MAE:  3.973749
# Epoch: 0450 Training MAE= 3.441026677
# Validation MAE:  3.447697
# Test MAE:  3.9622505
# Epoch: 0451 Training MAE= 3.442460185
# Validation MAE:  3.4693367
# Test MAE:  3.9853075
# Epoch: 0452 Training MAE= 3.442025623
# Validation MAE:  3.4419916
# Test MAE:  3.955911
# Epoch: 0453 Training MAE= 3.438922936
# Validation MAE:  3.4481034
# Test MAE:  3.9645011
# Epoch: 0454 Training MAE= 3.440841071
# Validation MAE:  3.458223
# Test MAE:  3.9754908
# Epoch: 0455 Training MAE= 3.441531901
# Validation MAE:  3.4604037
# Test MAE:  3.9749584
# Epoch: 0456 Training MAE= 3.440520782
# Validation MAE:  3.4536672
# Test MAE:  3.9691424
# Epoch: 0457 Training MAE= 3.439935813
# Validation MAE:  3.4614708
# Test MAE:  3.9781785
# Epoch: 0458 Training MAE= 3.441428905
# Validation MAE:  3.4631572
# Test MAE:  3.9804618
# Epoch: 0459 Training MAE= 3.439412616
# Validation MAE:  3.4496403
# Test MAE:  3.9661047
# Epoch: 0460 Training MAE= 3.438126462
# Validation MAE:  3.4527233
# Test MAE:  3.967625
# Epoch: 0461 Training MAE= 3.438150726
# Validation MAE:  3.4525945
# Test MAE:  3.9687588
# Epoch: 0462 Training MAE= 3.439048934
# Validation MAE:  3.4559443
# Test MAE:  3.9720924
# Epoch: 0463 Training MAE= 3.437823297
# Validation MAE:  3.446777
# Test MAE:  3.9638283
# Epoch: 0464 Training MAE= 3.437964114
# Validation MAE:  3.453329
# Test MAE:  3.9701495
# Epoch: 0465 Training MAE= 3.437551038
# Validation MAE:  3.4472897
# Test MAE:  3.963527
# Epoch: 0466 Training MAE= 3.437190762
# Validation MAE:  3.4469676
# Test MAE:  3.9643805
# Epoch: 0467 Training MAE= 3.437306881
# Validation MAE:  3.448105
# Test MAE:  3.9643857
# Epoch: 0468 Training MAE= 3.437235871
# Validation MAE:  3.4532762
# Test MAE:  3.9688478
# Epoch: 0469 Training MAE= 3.438142665
# Validation MAE:  3.4616983
# Test MAE:  3.9761076
# Epoch: 0470 Training MAE= 3.436109475
# Validation MAE:  3.4424691
# Test MAE:  3.957863
# Epoch: 0471 Training MAE= 3.435101915
# Validation MAE:  3.453968
# Test MAE:  3.9707794
# Epoch: 0472 Training MAE= 3.436072248
# Validation MAE:  3.4556754
# Test MAE:  3.9714348
# Epoch: 0473 Training MAE= 3.436251569
# Validation MAE:  3.448844
# Test MAE:  3.96686
# Epoch: 0474 Training MAE= 3.434319780
# Validation MAE:  3.442161
# Test MAE:  3.9577403
# Epoch: 0475 Training MAE= 3.432569436
# Validation MAE:  3.4377992
# Test MAE:  3.9545233
# Epoch: 0476 Training MAE= 3.435279846
# Validation MAE:  3.457502
# Test MAE:  3.975022
# Epoch: 0477 Training MAE= 3.435315775
# Validation MAE:  3.4392278
# Test MAE:  3.9567695
# Epoch: 0478 Training MAE= 3.433311091
# Validation MAE:  3.4446044
# Test MAE:  3.9630296
# Epoch: 0479 Training MAE= 3.434087603
# Validation MAE:  3.4460206
# Test MAE:  3.9633083
# Epoch: 0480 Training MAE= 3.435387065
# Validation MAE:  3.4553752
# Test MAE:  3.9690778
# Epoch: 0481 Training MAE= 3.435049020
# Validation MAE:  3.4478064
# Test MAE:  3.965053
# Epoch: 0482 Training MAE= 3.433188361
# Validation MAE:  3.4550138
# Test MAE:  3.972571
# Epoch: 0483 Training MAE= 3.432303285
# Validation MAE:  3.442354
# Test MAE:  3.9575613
# Epoch: 0484 Training MAE= 3.432330333
# Validation MAE:  3.4531662
# Test MAE:  3.9695551
# Epoch: 0485 Training MAE= 3.432618279
# Validation MAE:  3.4395673
# Test MAE:  3.9581466
# Epoch: 0486 Training MAE= 3.430105532
# Validation MAE:  3.4406772
# Test MAE:  3.9579272
# Epoch: 0487 Training MAE= 3.430292338
# Validation MAE:  3.4332197
# Test MAE:  3.950905
# Epoch: 0488 Training MAE= 3.431095094
# Validation MAE:  3.4433408
# Test MAE:  3.9615526
# Epoch: 0489 Training MAE= 3.431284243
# Validation MAE:  3.4348388
# Test MAE:  3.9531636
# Epoch: 0490 Training MAE= 3.430260930
# Validation MAE:  3.4364939
# Test MAE:  3.954063
# Epoch: 0491 Training MAE= 3.429286576
# Validation MAE:  3.4271107
# Test MAE:  3.9434655
# Epoch: 0492 Training MAE= 3.428935322
# Validation MAE:  3.4321027
# Test MAE:  3.9509618
# Epoch: 0493 Training MAE= 3.429769311
# Validation MAE:  3.4336493
# Test MAE:  3.9517024
# Epoch: 0494 Training MAE= 3.430481140
# Validation MAE:  3.435517
# Test MAE:  3.9551353
# Epoch: 0495 Training MAE= 3.429907167
# Validation MAE:  3.4375892
# Test MAE:  3.9559975
# Epoch: 0496 Training MAE= 3.430260596
# Validation MAE:  3.438417
# Test MAE:  3.957636
# Epoch: 0497 Training MAE= 3.431055801
# Validation MAE:  3.453138
# Test MAE:  3.972753
# Epoch: 0498 Training MAE= 3.431533745
# Validation MAE:  3.451065
# Test MAE:  3.9694605
# Epoch: 0499 Training MAE= 3.430854354
# Validation MAE:  3.4589462
# Test MAE:  3.9764106
# Epoch: 0500 Training MAE= 3.429958311
# Validation MAE:  3.4588904
# Test MAE:  3.9754086
# Epoch: 0501 Training MAE= 3.428461696
# Validation MAE:  3.453282
# Test MAE:  3.9706564
# Epoch: 0502 Training MAE= 3.427930754
# Validation MAE:  3.4516904
# Test MAE:  3.9706786
# Epoch: 0503 Training MAE= 3.426948877
# Validation MAE:  3.446821
# Test MAE:  3.9641213
# Epoch: 0504 Training MAE= 3.426885311
# Validation MAE:  3.443551
# Test MAE:  3.9637895
# Epoch: 0505 Training MAE= 3.426409685
# Validation MAE:  3.4426427
# Test MAE:  3.9620447
# Epoch: 0506 Training MAE= 3.425737722
# Validation MAE:  3.434063
# Test MAE:  3.9528098
# Epoch: 0507 Training MAE= 3.425080772
# Validation MAE:  3.439946
# Test MAE:  3.9588263
# Epoch: 0508 Training MAE= 3.425751862
# Validation MAE:  3.43279
# Test MAE:  3.9517195
# Epoch: 0509 Training MAE= 3.425142816
# Validation MAE:  3.4292924
# Test MAE:  3.9484994
# Epoch: 0510 Training MAE= 3.424666186
# Validation MAE:  3.4297528
# Test MAE:  3.9486194
# Epoch: 0511 Training MAE= 3.424424234
# Validation MAE:  3.4231093
# Test MAE:  3.9404278
# Epoch: 0512 Training MAE= 3.423577982
# Validation MAE:  3.4236083
# Test MAE:  3.942152
# Epoch: 0513 Training MAE= 3.422496410
# Validation MAE:  3.417081
# Test MAE:  3.9319174
# Epoch: 0514 Training MAE= 3.422327835
# Validation MAE:  3.417478
# Test MAE:  3.9329205
# Epoch: 0515 Training MAE= 3.422529122
# Validation MAE:  3.4158962
# Test MAE:  3.9303055
# Epoch: 0516 Training MAE= 3.422117461
# Validation MAE:  3.4147217
# Test MAE:  3.9281626
# Epoch: 0517 Training MAE= 3.422836277
# Validation MAE:  3.416744
# Test MAE:  3.9292803
# Epoch: 0518 Training MAE= 3.422820686
# Validation MAE:  3.4156268
# Test MAE:  3.927823
# Epoch: 0519 Training MAE= 3.423388076
# Validation MAE:  3.418039
# Test MAE:  3.9310603
# Epoch: 0520 Training MAE= 3.422496232
# Validation MAE:  3.416357
# Test MAE:  3.927772
# Epoch: 0521 Training MAE= 3.423150219
# Validation MAE:  3.4171634
# Test MAE:  3.9296525
# Epoch: 0522 Training MAE= 3.422875330
# Validation MAE:  3.4167671
# Test MAE:  3.9310505
# Epoch: 0523 Training MAE= 3.422832539
# Validation MAE:  3.4170077
# Test MAE:  3.9306188
# Epoch: 0524 Training MAE= 3.422910716
# Validation MAE:  3.4179492
# Test MAE:  3.930484
# Epoch: 0525 Training MAE= 3.421571182
# Validation MAE:  3.416146
# Test MAE:  3.928488
# Epoch: 0526 Training MAE= 3.421717466
# Validation MAE:  3.4171362
# Test MAE:  3.9300764
# Epoch: 0527 Training MAE= 3.421759811
# Validation MAE:  3.4186294
# Test MAE:  3.931907
# Epoch: 0528 Training MAE= 3.419790554
# Validation MAE:  3.4170933
# Test MAE:  3.9268262
# Epoch: 0529 Training MAE= 3.420768150
# Validation MAE:  3.4160619
# Test MAE:  3.9273627
# Epoch: 0530 Training MAE= 3.421556613
# Validation MAE:  3.4174664
# Test MAE:  3.9300396
# Epoch: 0531 Training MAE= 3.420664373
# Validation MAE:  3.4177017
# Test MAE:  3.928744
# Epoch: 0532 Training MAE= 3.420396226
# Validation MAE:  3.4196157
# Test MAE:  3.931996
# Epoch: 0533 Training MAE= 3.420511145
# Validation MAE:  3.418195
# Test MAE:  3.9310448
# Epoch: 0534 Training MAE= 3.419324005
# Validation MAE:  3.4173748
# Test MAE:  3.9279568
# Epoch: 0535 Training MAE= 3.419176372
# Validation MAE:  3.4158342
# Test MAE:  3.9281778
# Epoch: 0536 Training MAE= 3.420283483
# Validation MAE:  3.4173105
# Test MAE:  3.9297218
# Epoch: 0537 Training MAE= 3.419778184
# Validation MAE:  3.4200013
# Test MAE:  3.9274719
# Epoch: 0538 Training MAE= 3.419598267
# Validation MAE:  3.4189174
# Test MAE:  3.9310057
# Epoch: 0539 Training MAE= 3.419684749
# Validation MAE:  3.417915
# Test MAE:  3.9300356
# Epoch: 0540 Training MAE= 3.419778424
# Validation MAE:  3.4191144
# Test MAE:  3.9322455
# Epoch: 0541 Training MAE= 3.418347579
# Validation MAE:  3.4179494
# Test MAE:  3.927147
# Epoch: 0542 Training MAE= 3.418699697
# Validation MAE:  3.4179602
# Test MAE:  3.932399
# Epoch: 0543 Training MAE= 3.418143061
# Validation MAE:  3.4183283
# Test MAE:  3.9284453
# Epoch: 0544 Training MAE= 3.417905689
# Validation MAE:  3.4162712
# Test MAE:  3.9292638
# Epoch: 0545 Training MAE= 3.416517235
# Validation MAE:  3.4157023
# Test MAE:  3.9275346
# Epoch: 0546 Training MAE= 3.417378713
# Validation MAE:  3.419
# Test MAE:  3.9283154
# Epoch: 0547 Training MAE= 3.417536781
# Validation MAE:  3.4163284
# Test MAE:  3.927299
# Epoch: 0548 Training MAE= 3.418257138
# Validation MAE:  3.4190316
# Test MAE:  3.9316638
# Epoch: 0549 Training MAE= 3.417073570
# Validation MAE:  3.4158237
# Test MAE:  3.9269352
# Epoch: 0550 Training MAE= 3.416353892
# Validation MAE:  3.416772
# Test MAE:  3.92874
# Epoch: 0551 Training MAE= 3.416426498
# Validation MAE:  3.4151034
# Test MAE:  3.927075
# Epoch: 0552 Training MAE= 3.416904271
# Validation MAE:  3.416001
# Test MAE:  3.9268007
# Epoch: 0553 Training MAE= 3.415371148
# Validation MAE:  3.4135575
# Test MAE:  3.9232314
# Epoch: 0554 Training MAE= 3.417084083
# Validation MAE:  3.419161
# Test MAE:  3.9320068
# Epoch: 0555 Training MAE= 3.416776351
# Validation MAE:  3.4168973
# Test MAE:  3.9269412
# Epoch: 0556 Training MAE= 3.416136094
# Validation MAE:  3.416737
# Test MAE:  3.9292493
# Epoch: 0557 Training MAE= 3.415468106
# Validation MAE:  3.415083
# Test MAE:  3.9281797
# Epoch: 0558 Training MAE= 3.414807172
# Validation MAE:  3.4142535
# Test MAE:  3.9288807
# Epoch: 0559 Training MAE= 3.415517712
# Validation MAE:  3.4148095
# Test MAE:  3.9259357
# Epoch: 0560 Training MAE= 3.414179836
# Validation MAE:  3.4145103
# Test MAE:  3.9257708
# Epoch: 0561 Training MAE= 3.414009752
# Validation MAE:  3.4150763
# Test MAE:  3.927582
# Epoch: 0562 Training MAE= 3.414699277
# Validation MAE:  3.4149187
# Test MAE:  3.9260633
# Epoch: 0563 Training MAE= 3.414581969
# ...
# Test MAE:  3.8851724
# Epoch: 0816 Training MAE= 3.375420772
# Validation MAE:  3.385114
# Test MAE:  3.893067
# Epoch: 0817 Training MAE= 3.376615396
# Validation MAE:  3.3818138
# Test MAE:  3.8864045
# Epoch: 0818 Training MAE= 3.378127345
# Validation MAE:  3.3910818
# Test MAE:  3.8993616
# Epoch: 0819 Training MAE= 3.376179285
# Validation MAE:  3.3838828
# Test MAE:  3.8896496
# Epoch: 0820 Training MAE= 3.375313297
# Validation MAE:  3.3874638
# Test MAE:  3.8953097
# Epoch: 0821 Training MAE= 3.375156733
# Validation MAE:  3.3877864
# Test MAE:  3.895143
# Epoch: 0822 Training MAE= 3.373621238
# Validation MAE:  3.3831744
# Test MAE:  3.8891494
# Epoch: 0823 Training MAE= 3.383385615
# Validation MAE:  3.393193
# Test MAE:  3.8992145
# Epoch: 0824 Training MAE= 3.377180536
# Validation MAE:  3.3924868
# Test MAE:  3.898416
# Epoch: 0825 Training MAE= 3.376559404
# Validation MAE:  3.391517
# Test MAE:  3.8963132
# Epoch: 0826 Training MAE= 3.372992525
# Validation MAE:  3.3870835
# Test MAE:  3.8902612
# Epoch: 0827 Training MAE= 3.372930101
# Validation MAE:  3.383301
# Test MAE:  3.8889036
# Epoch: 0828 Training MAE= 3.370333754
# Validation MAE:  3.3838685
# Test MAE:  3.8898175
# Epoch: 0829 Training MAE= 3.372034817
# Validation MAE:  3.3799431
# Test MAE:  3.885021
# Epoch: 0830 Training MAE= 3.373950756
# Validation MAE:  3.3839965
# Test MAE:  3.888534
# Epoch: 0831 Training MAE= 3.379420510
# Validation MAE:  3.386185
# Test MAE:  3.8911152
# Epoch: 0832 Training MAE= 3.376233790
# Validation MAE:  3.3895762
# Test MAE:  3.8937051
# Epoch: 0833 Training MAE= 3.375432728
# Validation MAE:  3.386395
# Test MAE:  3.8917198
# Epoch: 0834 Training MAE= 3.374042494
# Validation MAE:  3.388959
# Test MAE:  3.8938663
# Epoch: 0835 Training MAE= 3.374293842
# Validation MAE:  3.3847356
# Test MAE:  3.890117
# Epoch: 0836 Training MAE= 3.371767604
# Validation MAE:  3.38378
# Test MAE:  3.8889594
# Epoch: 0837 Training MAE= 3.372846172
# Validation MAE:  3.382914
# Test MAE:  3.8895388
# Epoch: 0838 Training MAE= 3.369705763
# Validation MAE:  3.3838038
# Test MAE:  3.889668
# Epoch: 0839 Training MAE= 3.372072273
# Validation MAE:  3.3810067
# Test MAE:  3.883993
# Epoch: 0840 Training MAE= 3.372907955
# Validation MAE:  3.386646
# Test MAE:  3.892664
# Epoch: 0841 Training MAE= 3.373048447
# Validation MAE:  3.3803437
# Test MAE:  3.8849008
# Epoch: 0842 Training MAE= 3.373972714
# Validation MAE:  3.3814292
# Test MAE:  3.886148
# Epoch: 0843 Training MAE= 3.372840217
# Validation MAE:  3.3846743
# Test MAE:  3.8920689
# Epoch: 0844 Training MAE= 3.371153328
# Validation MAE:  3.381903
# Test MAE:  3.8866034
# Epoch: 0845 Training MAE= 3.374190605
# Validation MAE:  3.3804893
# Test MAE:  3.8844984
# Epoch: 0846 Training MAE= 3.371105408
# Validation MAE:  3.383819
# Test MAE:  3.8901827
# Epoch: 0847 Training MAE= 3.372609226
# Validation MAE:  3.3939145
# Test MAE:  3.901779
# Epoch: 0848 Training MAE= 3.371160788
# Validation MAE:  3.3788383
# Test MAE:  3.8812475
# Epoch: 0849 Training MAE= 3.371157865
# Validation MAE:  3.3836443
# Test MAE:  3.8886502
# Epoch: 0850 Training MAE= 3.372340274
# Validation MAE:  3.3852797
# Test MAE:  3.891855
# Epoch: 0851 Training MAE= 3.372498646
# Validation MAE:  3.4016829
# Test MAE:  3.9098268
# Epoch: 0852 Training MAE= 3.373130225
# Validation MAE:  3.3829713
# Test MAE:  3.889281
# Epoch: 0853 Training MAE= 3.371676175
# Validation MAE:  3.4055152
# Test MAE:  3.9141555
# Epoch: 0854 Training MAE= 3.375531437
# Validation MAE:  3.3820698
# Test MAE:  3.8876028
# Epoch: 0855 Training MAE= 3.375077633
# Validation MAE:  3.3829212
# Test MAE:  3.8890285
# Epoch: 0856 Training MAE= 3.383385867
# Validation MAE:  3.3894165
# Test MAE:  3.9000735
# Epoch: 0857 Training MAE= 3.368497002
# Validation MAE:  3.3843465
# Test MAE:  3.8862166
# Epoch: 0858 Training MAE= 3.375190373
# Validation MAE:  3.3860257
# Test MAE:  3.8949654
# Epoch: 0859 Training MAE= 3.369503824
# Validation MAE:  3.3855112
# Test MAE:  3.8901403
# Epoch: 0860 Training MAE= 3.373456261
# Validation MAE:  3.3874345
# Test MAE:  3.895843
# Epoch: 0861 Training MAE= 3.368706494
# Validation MAE:  3.3830307
# Test MAE:  3.8882828
# Epoch: 0862 Training MAE= 3.374438673
# Validation MAE:  3.3876894
# Test MAE:  3.897734
# Epoch: 0863 Training MAE= 3.367196652
# Validation MAE:  3.3821998
# Test MAE:  3.8864129
# Epoch: 0864 Training MAE= 3.370000240
# Validation MAE:  3.38377
# Test MAE:  3.8895254
# Epoch: 0865 Training MAE= 3.366519250
# Validation MAE:  3.3815837
# Test MAE:  3.8864465
# Epoch: 0866 Training MAE= 3.371720327
# Validation MAE:  3.382336
# Test MAE:  3.8876607
# Epoch: 0867 Training MAE= 3.367431445
# Validation MAE:  3.3803198
# Test MAE:  3.8857112
# Epoch: 0868 Training MAE= 3.369199495
# Validation MAE:  3.379378
# Test MAE:  3.884398
# Epoch: 0869 Training MAE= 3.368543833
# Validation MAE:  3.3833714
# Test MAE:  3.888651
# Epoch: 0870 Training MAE= 3.375804505
# Validation MAE:  3.3880022
# Test MAE:  3.8962564
# Epoch: 0871 Training MAE= 3.368015060
# Validation MAE:  3.3835902
# Test MAE:  3.8905659
# Epoch: 0872 Training MAE= 3.373678845
# Validation MAE:  3.3874993
# Test MAE:  3.8964546
# Epoch: 0873 Training MAE= 3.367831754
# Validation MAE:  3.3842
# Test MAE:  3.8902702
# Epoch: 0874 Training MAE= 3.364701302
# Validation MAE:  3.3803504
# Test MAE:  3.8841593
# Epoch: 0875 Training MAE= 3.358964438
# Validation MAE:  3.4006987
# Test MAE:  3.9055848
# Epoch: 0876 Training MAE= 3.370679065
# Validation MAE:  3.384283
# Test MAE:  3.889776
# Epoch: 0877 Training MAE= 3.372032920
# Validation MAE:  3.3828154
# Test MAE:  3.8891232
# Epoch: 0878 Training MAE= 3.380030506
# Validation MAE:  3.394913
# Test MAE:  3.9054363
# Epoch: 0879 Training MAE= 3.374540134
# Validation MAE:  3.4033566
# Test MAE:  3.911934
# Epoch: 0880 Training MAE= 3.381135714
# Validation MAE:  3.4310555
# Test MAE:  3.9441855
# Epoch: 0881 Training MAE= 3.386181289
# Validation MAE:  3.3905354
# Test MAE:  3.895631
# Epoch: 0882 Training MAE= 3.368857237
# Validation MAE:  3.4051507
# Test MAE:  3.9104404
# Epoch: 0883 Training MAE= 3.373118591
# Validation MAE:  3.3885143
# Test MAE:  3.8915367
# Epoch: 0884 Training MAE= 3.367107284
# Validation MAE:  3.403454
# Test MAE:  3.9101202
# Epoch: 0885 Training MAE= 3.369621208
# Validation MAE:  3.3983634
# Test MAE:  3.9050326
# Epoch: 0886 Training MAE= 3.367469356
# Validation MAE:  3.4021375
# Test MAE:  3.9083831
# Epoch: 0887 Training MAE= 3.368269731
# Validation MAE:  3.3973496
# Test MAE:  3.903464
# Epoch: 0888 Training MAE= 3.365220214
# Validation MAE:  3.40116
# Test MAE:  3.9066381
# Epoch: 0889 Training MAE= 3.367632037
# Validation MAE:  3.4000835
# Test MAE:  3.905721
# Epoch: 0890 Training MAE= 3.366918768
# Validation MAE:  3.4010253
# Test MAE:  3.909337
# Epoch: 0891 Training MAE= 3.367311997
# Validation MAE:  3.4015238
# Test MAE:  3.9075682
# Epoch: 0892 Training MAE= 3.366510679
# Validation MAE:  3.399667
# Test MAE:  3.9064171
# Epoch: 0893 Training MAE= 3.366879087
# Validation MAE:  3.4061377
# Test MAE:  3.9121594
# Epoch: 0894 Training MAE= 3.366705299
# Validation MAE:  3.4019659
# Test MAE:  3.9076252
# Epoch: 0895 Training MAE= 3.366132213
# Validation MAE:  3.404765
# Test MAE:  3.9099967
# Epoch: 0896 Training MAE= 3.366836672
# Validation MAE:  3.4012084
# Test MAE:  3.9089265
# Epoch: 0897 Training MAE= 3.365118595
# Validation MAE:  3.4000347
# Test MAE:  3.906245
# Epoch: 0898 Training MAE= 3.364936984
# Validation MAE:  3.398366
# Test MAE:  3.9056344
# Epoch: 0899 Training MAE= 3.365395027
# Validation MAE:  3.4025266
# Test MAE:  3.9095085
# Epoch: 0900 Training MAE= 3.366114044
# Validation MAE:  3.4013946
# Test MAE:  3.9093063
# Epoch: 0901 Training MAE= 3.365725465
# Validation MAE:  3.4006963
# Test MAE:  3.9074864
# Epoch: 0902 Training MAE= 3.366876017
# Validation MAE:  3.3990254
# Test MAE:  3.907368
# Epoch: 0903 Training MAE= 3.365305856
# Validation MAE:  3.398955
# Test MAE:  3.9047053
# Epoch: 0904 Training MAE= 3.365845954
# Validation MAE:  3.4015043
# Test MAE:  3.9093997
# Epoch: 0905 Training MAE= 3.366326157
# Validation MAE:  3.403293
# Test MAE:  3.909867
# Epoch: 0906 Training MAE= 3.366648649
# Validation MAE:  3.4006963
# Test MAE:  3.9090543
# Epoch: 0907 Training MAE= 3.365397232
# Validation MAE:  3.4006352
# Test MAE:  3.906555
# Epoch: 0908 Training MAE= 3.366207673
# Validation MAE:  3.4061706
# Test MAE:  3.9143653
# Epoch: 0909 Training MAE= 3.366520931
# Validation MAE:  3.4064384
# Test MAE:  3.9125836
# Epoch: 0910 Training MAE= 3.366398801
# Validation MAE:  3.4055562
# Test MAE:  3.9138324
# Epoch: 0911 Training MAE= 3.364984035
# Validation MAE:  3.4026816
# Test MAE:  3.9099884
# Epoch: 0912 Training MAE= 3.363242241
# Validation MAE:  3.3998883
# Test MAE:  3.9059122
# Epoch: 0913 Training MAE= 3.364514371
# Validation MAE:  3.403689
# Test MAE:  3.909325
# Epoch: 0914 Training MAE= 3.363640236
# Validation MAE:  3.4002051
# Test MAE:  3.9069326
# Epoch: 0915 Training MAE= 3.363337280
# Validation MAE:  3.4007382
# Test MAE:  3.9061494
# Epoch: 0916 Training MAE= 3.364019978
# Validation MAE:  3.3968115
# Test MAE:  3.904548
# Epoch: 0917 Training MAE= 3.362242195
# Validation MAE:  3.3945315
# Test MAE:  3.9015315
# Epoch: 0918 Training MAE= 3.361782863
# Validation MAE:  3.3930745
# Test MAE:  3.9005349
# Epoch: 0919 Training MAE= 3.361036758
# Validation MAE:  3.3957653
# Test MAE:  3.9031444
# Epoch: 0920 Training MAE= 3.364701171
# Validation MAE:  3.3895566
# Test MAE:  3.8961642
# Epoch: 0921 Training MAE= 3.361846298
# Validation MAE:  3.3893163
# Test MAE:  3.895912
# Epoch: 0922 Training MAE= 3.363539220
# Validation MAE:  3.3863761
# Test MAE:  3.8941655
# Epoch: 0923 Training MAE= 3.363840102
# Validation MAE:  3.3912323
# Test MAE:  3.8986895
# Epoch: 0924 Training MAE= 3.366246228
# Validation MAE:  3.3857033
# Test MAE:  3.8941665
# Epoch: 0925 Training MAE= 3.358866398
# Validation MAE:  3.393371
# Test MAE:  3.899121
# Epoch: 0926 Training MAE= 3.363261063
# Validation MAE:  3.3843462
# Test MAE:  3.8919182
# Epoch: 0927 Training MAE= 3.367017847
# Validation MAE:  3.3836048
# Test MAE:  3.8909156
# Epoch: 0928 Training MAE= 3.364912223
# Validation MAE:  3.3792515
# Test MAE:  3.8860607
# Epoch: 0929 Training MAE= 3.360385218
# Validation MAE:  3.3943217
# Test MAE:  3.9012835
# Epoch: 0930 Training MAE= 3.367525609
# Validation MAE:  3.3817215
# Test MAE:  3.889821
# Epoch: 0931 Training MAE= 3.361631520
# Validation MAE:  3.3839874
# Test MAE:  3.8907058
# Epoch: 0932 Training MAE= 3.362655882
# Validation MAE:  3.376869
# Test MAE:  3.8837903
# Epoch: 0933 Training MAE= 3.359179643
# Validation MAE:  3.3918123
# Test MAE:  3.8990817
# Epoch: 0934 Training MAE= 3.361963710
# Validation MAE:  3.3917954
# Test MAE:  3.8993611
# Epoch: 0935 Training MAE= 3.361517669
# Validation MAE:  3.3985517
# Test MAE:  3.9071708
# Epoch: 0936 Training MAE= 3.368589479
# Validation MAE:  3.377736
# Test MAE:  3.8828175
# Epoch: 0937 Training MAE= 3.363417269
# Validation MAE:  3.378868
# Test MAE:  3.8856366
# Epoch: 0938 Training MAE= 3.366325782
# Validation MAE:  3.3812065
# Test MAE:  3.8893461
# Epoch: 0939 Training MAE= 3.362086819
# Validation MAE:  3.3803167
# Test MAE:  3.887102
# Epoch: 0940 Training MAE= 3.360225373
# Validation MAE:  3.378173
# Test MAE:  3.8838823
# Epoch: 0941 Training MAE= 3.358769105
# Validation MAE:  3.394666
# Test MAE:  3.9026241
# Epoch: 0942 Training MAE= 3.364831442
# Validation MAE:  3.3846838
# Test MAE:  3.891488
# Epoch: 0943 Training MAE= 3.366805838
# Validation MAE:  3.381041
# Test MAE:  3.8881276
# Epoch: 0944 Training MAE= 3.366406676
# Validation MAE:  3.3861473
# Test MAE:  3.8929827
# Epoch: 0945 Training MAE= 3.358292547
# Validation MAE:  3.3773415
# Test MAE:  3.8827107
# Epoch: 0946 Training MAE= 3.356270225
# Validation MAE:  3.385062
# Test MAE:  3.8896027
# Epoch: 0947 Training MAE= 3.355281684
# Validation MAE:  3.4043458
# Test MAE:  3.9099526
# Epoch: 0948 Training MAE= 3.361074363
# Validation MAE:  3.388998
# Test MAE:  3.8947115
# Epoch: 0949 Training MAE= 3.364304537
# Validation MAE:  3.4030628
# Test MAE:  3.9100735
# Epoch: 0950 Training MAE= 3.375572129
# Validation MAE:  3.3813403
# Test MAE:  3.8888636
# Epoch: 0951 Training MAE= 3.360717546
# Validation MAE:  3.37962
# Test MAE:  3.885508
# Epoch: 0952 Training MAE= 3.359634251
# Validation MAE:  3.3782835
# Test MAE:  3.884492
# Epoch: 0953 Training MAE= 3.361400000
# Validation MAE:  3.3826087
# Test MAE:  3.888441
# Epoch: 0954 Training MAE= 3.366945085
# Validation MAE:  3.3882291
# Test MAE:  3.8950837
# Epoch: 0955 Training MAE= 3.360142039
# Validation MAE:  3.3815472
# Test MAE:  3.8865979
# Epoch: 0956 Training MAE= 3.360467827
# Validation MAE:  3.3836663
# Test MAE:  3.890415
# Epoch: 0957 Training MAE= 3.361804115
# Validation MAE:  3.3811665
# Test MAE:  3.8872306
# Epoch: 0958 Training MAE= 3.359335768
# Validation MAE:  3.3820667
# Test MAE:  3.8867576
# Epoch: 0959 Training MAE= 3.361176628
# Validation MAE:  3.3820262
# Test MAE:  3.8895082
# Epoch: 0960 Training MAE= 3.364158343
# Validation MAE:  3.3881376
# Test MAE:  3.8948424
# Epoch: 0961 Training MAE= 3.360921244
# Validation MAE:  3.37854
# Test MAE:  3.8829737
# Epoch: 0962 Training MAE= 3.354829514
# Validation MAE:  3.385059
# Test MAE:  3.8893926
# Epoch: 0963 Training MAE= 3.358145548
# Validation MAE:  3.3942642
# Test MAE:  3.901283
# Epoch: 0964 Training MAE= 3.365383439
# Validation MAE:  3.383951
# Test MAE:  3.8896286
# Epoch: 0965 Training MAE= 3.367032406
# Validation MAE:  3.3845243
# Test MAE:  3.8916783
# Epoch: 0966 Training MAE= 3.361518808
# Validation MAE:  3.3863976
# Test MAE:  3.891515
# Epoch: 0967 Training MAE= 3.358621498
# Validation MAE:  3.3778436
# Test MAE:  3.8825057
# Epoch: 0968 Training MAE= 3.356301222
# Validation MAE:  3.3827014
# Test MAE:  3.8866212
# Epoch: 0969 Training MAE= 3.356367657
# Validation MAE:  3.3805857
# Test MAE:  3.8842995
# Epoch: 0970 Training MAE= 3.354377740
# Validation MAE:  3.4027512
# Test MAE:  3.9071808
# Epoch: 0971 Training MAE= 3.366281259
# Validation MAE:  3.3831656
# Test MAE:  3.8893306
# Epoch: 0972 Training MAE= 3.367721970
# Validation MAE:  3.4000647
# Test MAE:  3.9055526
# Epoch: 0973 Training MAE= 3.372243093
# Validation MAE:  3.406959
# Test MAE:  3.9171154
# Epoch: 0974 Training MAE= 3.372355809
# Validation MAE:  3.387238
# Test MAE:  3.892477
# Epoch: 0975 Training MAE= 3.360160766
# Validation MAE:  3.3992133
# Test MAE:  3.9041057
# Epoch: 0976 Training MAE= 3.363868625
# Validation MAE:  3.3976636
# Test MAE:  3.9007666
# Epoch: 0977 Training MAE= 3.360914984
# Validation MAE:  3.4007044
# Test MAE:  3.9046764
# Epoch: 0978 Training MAE= 3.361486254
# Validation MAE:  3.3988545
# Test MAE:  3.9021938
# Epoch: 0979 Training MAE= 3.359027290
# Validation MAE:  3.3977046
# Test MAE:  3.901824
# Epoch: 0980 Training MAE= 3.359857359
# Validation MAE:  3.4002867
# Test MAE:  3.903272
# Epoch: 0981 Training MAE= 3.358959675
# Validation MAE:  3.3965201
# Test MAE:  3.8997405
# Epoch: 0982 Training MAE= 3.358508074
# Validation MAE:  3.3988466
# Test MAE:  3.9018962
# Epoch: 0983 Training MAE= 3.358894640
# Validation MAE:  3.3925734
# Test MAE:  3.895896
# Epoch: 0984 Training MAE= 3.358318253
# Validation MAE:  3.3969102
# Test MAE:  3.9005184
# Epoch: 0985 Training MAE= 3.359493183
# Validation MAE:  3.394146
# Test MAE:  3.8988981
# Epoch: 0986 Training MAE= 3.358020458
# Validation MAE:  3.396792
# Test MAE:  3.9011736
# Epoch: 0987 Training MAE= 3.359700437
# Validation MAE:  3.3936667
# Test MAE:  3.8983514
# Epoch: 0988 Training MAE= 3.357647218
# Validation MAE:  3.3970706
# Test MAE:  3.9008238
# Epoch: 0989 Training MAE= 3.360316990
# Validation MAE:  3.3982136
# Test MAE:  3.9023266
# Epoch: 0990 Training MAE= 3.358566609
# Validation MAE:  3.3993912
# Test MAE:  3.9033813
# Epoch: 0991 Training MAE= 3.360521160
# Validation MAE:  3.3993442
# Test MAE:  3.9038858
# Epoch: 0992 Training MAE= 3.357259076
# Validation MAE:  3.399367
# Test MAE:  3.901627
# Epoch: 0993 Training MAE= 3.358865732
# Validation MAE:  3.3962467
# Test MAE:  3.899165
# Epoch: 0994 Training MAE= 3.357760180
# Validation MAE:  3.3988783
# Test MAE:  3.9014823
# Epoch: 0995 Training MAE= 3.359079907
# Validation MAE:  3.3986113
# Test MAE:  3.902412
# Epoch: 0996 Training MAE= 3.357312115
# Validation MAE:  3.3980908
# Test MAE:  3.9013186
# Epoch: 0997 Training MAE= 3.357657661
# Validation MAE:  3.3923771
# Test MAE:  3.894763
# Epoch: 0998 Training MAE= 3.356995015
# Validation MAE:  3.3990886
# Test MAE:  3.903291
# Epoch: 0999 Training MAE= 3.356832533
# Validation MAE:  3.3909407
# Test MAE:  3.8950014
# Epoch: 1000 Training MAE= 3.355653998
# Validation MAE:  3.3945317
# Test MAE:  3.8979836
# epoch is  999
# training error is  3.3626558817665124
# Optimization Finished! the lowest validation MAE is  3.376869
# The test MAE is  3.8837903
# 0:15:45.208130

# %%
All_pred_tf = tf.convert_to_tensor(
    All_pred,
    dtype=np.float32,
    name=None,
    preferred_dtype=None
)

#All_Y = scaler.inverse_transform(All_Y)

All_Y_tf =  tf.convert_to_tensor(
    All_Y,
    dtype=np.float32,
    name=None,
    preferred_dtype=None
)

predic_res_re = tf.reshape(All_pred_tf, [All_pred.shape[0], sn, horizon])

test_Y_re = tf.reshape(All_Y_tf, [All_pred.shape[0], sn, horizon])

cost_by_hor = []
with tf.Session() as sess:  
    for hor_i in range(horizon):
        cost_by_hor.append(masked_mae_tf(predic_res_re[:, :, 0:hor_i+1], test_Y_re[:, :, 0:hor_i+1], 0).eval())

# %%
cost_by_hor

# %%
np.savetxt("../../data/trajectory/gcnn_prediction.csv", All_pred, delimiter = ',')
np.savetxt("../../data/trajectory/gcnn_prediction_Y.csv", All_Y, delimiter = ',')

# %%
All_pred_tf.shape
# Out:
# TensorShape([Dimension(6850), Dimension(2484)])
